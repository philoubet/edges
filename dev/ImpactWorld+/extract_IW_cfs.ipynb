# %%
import pandas as pd

# %%
cfs = pd.read_excel("impact_world_plus_2.1_dev.xlsx", sheet_name="Sheet1")
cfs = cfs.loc[cfs["CF value"]!=0]
cfs = cfs.loc[
    (cfs["Native geographical resolution scale"] == "Country")
    | (cfs["Native geographical resolution scale"] == "Continent")
     ]
cfs.head()
# Out:
#       Unnamed: 0           Impact category    CF unit Compartment  \
# 3050        3050  Freshwater acidification  kg SO2 eq         Air
# 3051        3051  Freshwater acidification  kg SO2 eq         Air
# 3052        3052  Freshwater acidification  kg SO2 eq         Air
# 3053        3053  Freshwater acidification  kg SO2 eq         Air
# 3054        3054  Freshwater acidification  kg SO2 eq         Air
#
#                  Sub-compartment Elem flow name CAS number  CF value  \
# 3050               (unspecified)    Ammonia, AD  7664-41-7  0.180141
# 3051                  high. pop.    Ammonia, AD  7664-41-7  0.180141
# 3052                   low. pop.    Ammonia, AD  7664-41-7  0.180141
# 3053  stratosphere + troposphere    Ammonia, AD  7664-41-7  0.180141
# 3054                      indoor    Ammonia, AD  7664-41-7  0.180141
#
#      Elem flow unit MP or Damage Native geographical resolution scale
# 3050             kg     Midpoint                              Country
# 3051             kg     Midpoint                              Country
# 3052             kg     Midpoint                              Country
# 3053             kg     Midpoint                              Country
# 3054             kg     Midpoint                              Country

# %%
# create a column called `location` where we extract teh location from the `Elem flow name` column
# location are capital letters after the last comma
cfs["location"] = cfs["Elem flow name"].str.extract(r',\s*([A-Z-]+)$')
cfs["location"].unique()
# Out:
# array(['AD', 'AE', 'AF', 'AG', 'AI', 'AL', 'AM', 'AO', 'AQ', 'AR', 'AS',
#        'AT', 'AU', 'AU-NSW', 'AU-QLD', 'AU-SA', 'AU-TAS', 'AU-VIC',
#        'AU-WA', 'AW', 'AZ', 'BA', 'BB', 'BD', 'BE', 'BF', 'BG', 'BH',
#        'BI', 'BJ', 'BN', 'BO', 'BR', 'BR-AC', 'BR-AL', 'BR-AM', 'BR-AP',
#        'BR-BA', 'BR-CE', 'BR-DF', 'BR-ES', 'BR-GO', 'BR-MA', 'BR-MG',
#        'BR-MS', 'BR-MT', nan, 'BR-PA', 'BR-PB', 'BR-PE', 'BR-PI', 'BR-PR',
#        'BR-RJ', 'BR-RN', 'BR-RO', 'BR-RR', 'BR-RS', 'BR-SC', 'BR-SE',
#        'BR-SP', 'BR-TO', 'BS', 'BT', 'BV', 'BW', 'BY', 'BZ', 'CA',
#        'CA-AB', 'CA-BC', 'CA-MB', 'CA-NB', 'CA-NF', 'CA-NS', 'CA-NT',
#        'CA-NU', 'CA-ON', 'CA-PE', 'CA-QC', 'CA-SK', 'CA-YK', 'CD', 'CF',
#        'CG', 'CH', 'CI', 'CK', 'CL', 'CM', 'CN', 'CN-AH', 'CN-BJ',
#        'CN-CCG', 'CN-CQ', 'CN-CSG', 'CN-ECGC', 'CN-FJ', 'CN-GD', 'CN-GS',
#        'CN-GX', 'CN-GZ', 'CN-HA', 'CN-HB', 'CN-HE', 'CN-HL', 'CN-HN',
#        'CN-HU', 'CN-JL', 'CN-JS', 'CN-JX', 'CN-LN', 'CN-NCGC', 'CN-NECG',
#        'CN-NM', 'CN-NWG', 'CN-NX', 'CN-QH', 'CN-SA', 'CN-SC', 'CN-SD',
#        'CN-SGCC', 'CN-SH', 'CN-SWG', 'CN-SX', 'CN-TJ', 'CN-XJ', 'CN-XZ',
#        'CN-YN', 'CN-ZJ', 'CO', 'CR', 'CU', 'CV', 'CW', 'CX', 'CY', 'CZ',
#        'DE', 'DJ', 'DK', 'DM', 'DO', 'DZ', 'EC', 'EE', 'EG', 'EH', 'ER',
#        'ES', 'ET', 'FI', 'FJ', 'FK', 'FM', 'FO', 'FR', 'GA', 'GB', 'GD',
#        'GE', 'GF', 'GH', 'GL', 'GM', 'GN', 'GP', 'GQ', 'GR', 'GS', 'GT',
#        'GU', 'GW', 'GY', 'HK', 'HN', 'HR', 'HT', 'HU', 'ID', 'IE', 'IL',
#        'IM', 'IN', 'IN-AP', 'IN-AR', 'IN-AS', 'IN-BR', 'IN-CH', 'IN-CT',
#        'IN-DD', 'IN-DL', 'IN-DN', 'IN-GA', 'IN-GJ', 'IN-HP', 'IN-HR',
#        'IN-JH', 'IN-JK', 'IN-KA', 'IN-KL', 'IN-MH', 'IN-ML', 'IN-MN',
#        'IN-MP', 'IN-MZ', 'IN-NL', 'IN-OR', 'IN-PB', 'IN-PY', 'IN-RJ',
#        'IN-SK', 'IN-TN', 'IN-TR', 'IN-UP', 'IN-UT', 'IN-WB', 'IO', 'IQ',
#        'IR', 'IS', 'IT', 'JE', 'JM', 'JO', 'JP', 'KE', 'KG', 'KH', 'KI',
#        'KM', 'KN', 'KP', 'KR', 'KW', 'KZ', 'LA', 'LB', 'LC', 'LI', 'LK',
#        'LR', 'LS', 'LT', 'LU', 'LV', 'LY', 'MA', 'MD', 'ME', 'MG', 'MK',
#        'ML', 'MM', 'MN', 'MQ', 'MR', 'MS', 'MT', 'MU', 'MW', 'MX', 'MY',
#        'MZ', 'NA', 'NC', 'NE', 'NG', 'NI', 'NL', 'NO', 'NP', 'NU', 'NZ',
#        'OCE', 'OM', 'PA', 'PE', 'PF', 'PG', 'PH', 'PK', 'PL', 'PR', 'PS',
#        'PT', 'PW', 'PY', 'QA', 'RAF', 'RAS', 'RE', 'RER', 'RLA', 'RME',
#        'RNA', 'RO', 'RS', 'RU', 'RW', 'SA', 'SB', 'SC', 'SD', 'SE', 'SG',
#        'SH', 'SI', 'SJ', 'SK', 'SL', 'SN', 'SO', 'SR', 'SS', 'ST', 'SV',
#        'SY', 'SZ', 'TC', 'TD', 'TF', 'TG', 'TH', 'TJ', 'TL', 'TM', 'TN',
#        'TO', 'TR', 'TT', 'TW', 'TZ', 'UA', 'UG', 'UN-OCEANIA', 'US',
#        'US-ASCC', 'US-CA', 'US-CO', 'US-FL', 'US-HICC', 'US-IA', 'US-ID',
#        'US-IL', 'US-IN', 'US-MN', 'US-MRO', 'US-ND', 'US-NE', 'US-NPCC',
#        'US-OH', 'US-OR', 'US-PR', 'US-RFC', 'US-SD', 'US-SERC', 'US-TRE',
#        'US-WA', 'US-WECC', 'US-WI', 'UY', 'UZ', 'VC', 'VE', 'VG', 'VN',
#        'VU', 'WF', 'WS', 'XK', 'YE', 'YT', 'ZA', 'ZM', 'ZW', 'BM', 'CC',
#        'GG', 'GI', 'MC', 'MH', 'MV', 'NR', 'PN', 'SM', 'TV', 'VA', 'CS',
#        'AX', 'BQ', 'KY', 'MF', 'MO', 'MP', 'NF', 'UM', 'VI', 'SAS',
#        'UN-SEASIA', 'WECC', 'ENTSO-E', 'NORDEL', 'UCTE', 'WEU', 'AU-ACT',
#        'AU-JBT', 'AU-NT', 'IN-AN', 'IN-LA', 'IN-TG', 'US-AK', 'US-AL',
#        'US-AR', 'US-AZ', 'US-CT', 'US-DC', 'US-DE', 'US-GA', 'US-HI',
#        'US-KS', 'US-KY', 'US-LA', 'US-MA', 'US-MD', 'US-ME', 'US-MI',
#        'US-MO', 'US-MS', 'US-MT', 'US-NC', 'US-NH', 'US-NJ', 'US-NM',
#        'US-NV', 'US-NY', 'US-OK', 'US-PA', 'US-RI', 'US-SC', 'US-TN',
#        'US-TX', 'US-UT', 'US-VA', 'US-VT', 'US-WV', 'US-WY'], dtype=object)

# %%
# fix values under `Elem flow name` column, by removing the location and the comma preceding it
cfs["Elem flow name"] = cfs["Elem flow name"].str.rsplit(', ', n=1).str[0]
cfs["Elem flow name"].unique()
# Out:
# array(['Ammonia', 'Ammonia, as N', 'Ammonium carbonate',
#        'Ammonium nitrate', 'Ammonium, ion', 'Nitrate', 'Nitric oxide',
#        'Nitrite', 'Nitrogen dioxide', 'Nitrogen oxides', 'Sulfate',
#        'Sulfur dioxide', 'Sulfur trioxide', 'Sulfuric acid', 'BOD', 'COD',
#        'Phosphate', 'Phosphoric acid', 'Phosphorus pentoxide',
#        'Phosphorus', 'Occupation, agriculture, mosaic (agroforestry)',
#        'Occupation, annual crops', 'Occupation, artificial areas',
#        'Occupation, forest, used', 'Occupation, pasture/meadow',
#        'Occupation, permanent crops', 'Occupation, secondary vegetation',
#        'Occupation, unspecified',
#        'Transformation, from agriculture, mosaic (agroforestry)',
#        'Transformation, from annual crops',
#        'Transformation, from artificial areas',
#        'Transformation, from forest, used',
#        'Transformation, from pasture/meadow',
#        'Transformation, from permanent crops',
#        'Transformation, from secondary vegetation',
#        'Transformation, from unspecified',
#        'Transformation, to agriculture, mosaic (agroforestry)',
#        'Transformation, to annual crops',
#        'Transformation, to artificial areas',
#        'Transformation, to forest, used',
#        'Transformation, to pasture/meadow',
#        'Transformation, to permanent crops',
#        'Transformation, to secondary vegetation',
#        'Transformation, to unspecified', 'HNO3', 'Nitric acid',
#        'Ammonia, Europe', 'Ammonia, IAI Area', 'Ammonia, IAI Area, Asia',
#        'Nitrogen oxides, Europe', 'Nitrogen oxides, IAI Area',
#        'Nitrogen oxides, IAI Area, Asia', 'Particulates, < 10 um',
#        'Particulates, < 10 um, Europe', 'Particulates, < 10 um, IAI Area',
#        'Particulates, < 10 um, IAI Area, Asia', 'Particulates, < 2.5 um',
#        'Particulates, < 2.5 um, Europe',
#        'Particulates, < 2.5 um, IAI Area',
#        'Particulates, < 2.5 um, IAI Area, Asia', 'Sulfur dioxide, Europe',
#        'Sulfur dioxide, IAI Area', 'Sulfur dioxide, IAI Area, Asia',
#        'Water', 'Water, agri',
#        'Water, cooling, unspecified natural origin', 'Water, lake',
#        'Water, non-agri', 'Water, river',
#        'Water, unspecified natural origin', 'Water, well, in ground',
#        'Acoupa weakfish', 'African moonfish', 'African sicklefish',
#        'Alaska plaice', 'Alaska pollock(=Walleye poll.)', 'Albacore',
#        'Alewife', 'Alexandria pompano', 'Alfonsino',
#        'Amer. plaice(=Long rough dab)', 'American angler', 'American eel',
#        'American shad', 'Anchoveta(=Peruvian anchovy)', 'Angler(=Monk)',
#        'Angolan dentex', 'Annular seabream', 'Antarctic toothfish',
#        'Araucanian herring', 'Argentine anchovy', 'Argentine angelshark',
#        'Argentine conger', 'Argentine croaker', 'Argentine hake',
#        'Argentine menhaden', 'Argentine seabass', 'Argentine',
#        'Argentinian sandperch', 'Arrowtooth flounder', 'Atka mackerel',
#        'Atlantic Spanish mackerel', 'Atlantic anchoveta',
#        'Atlantic bluefin tuna', 'Atlantic bonito', 'Atlantic bumper',
#        'Atlantic butterfish', 'Atlantic chub mackerel', 'Atlantic cod',
#        'Atlantic croaker', 'Atlantic emperor', 'Atlantic halibut',
#        'Atlantic herring', 'Atlantic horse mackerel', 'Atlantic mackerel',
#        'Atlantic menhaden', 'Atlantic moonfish', 'Atlantic pomfret',
#        'Atlantic sailfish', 'Atlantic salmon', 'Atlantic saury',
#        'Atlantic silverside', 'Atlantic thread herring',
#        'Atlantic tomcod', 'Atlantic white marlin', 'Atlantic wolffish',
#        'Australian pilchard', 'Australian salmon', 'Axillary seabream',
#        "Baird's slickhead", 'Bali sardinella', 'Ballyhoo halfbeak',
#        'Barramundi(=Giant seaperch)', 'Barred grunt', 'Bartail flathead',
#        'Basking shark', 'Bastard halibut', 'Beaked redfish',
#        'Bearded brotula', 'Benguela hake', 'Big-scale sand smelt',
#        'Bigeye grunt', 'Bigeye scad', 'Bigeye tuna',
#        'Black and Caspian Sea sprat', 'Black cardinal fish',
#        'Black cusk-eel', 'Black drum', 'Black marlin', 'Black oreo',
#        'Black pomfret', 'Black scabbardfish', 'Black seabass',
#        'Black seabream', 'Black skipjack', 'Black-streaked monocle bream',
#        'Blackbanded trevally', 'Blackbelly rosefish',
#        'Blackfin goosefish', 'Blackfin icefish', 'Blackfin tuna',
#        'Blackhead seabream', 'Blackmouth catshark', 'Blackmouth croaker',
#        'Blackspot(=red) seabream', 'Blackthroat seaperch',
#        'Blacktip shark', 'Blonde ray', 'Blotched picarel',
#        'Blue butterfish', 'Blue grenadier', 'Blue jack mackerel',
#        'Blue ling', 'Blue mackerel', 'Blue marlin', 'Blue runner',
#        'Blue shark', 'Blue skate', 'Blue whiting(=Poutassou)',
#        'Bluefin gurnard', 'Bluefish', 'Bluenose warehou',
#        'Bluespine unicornfish', 'Bluespot mullet', 'Boarfish',
#        'Bobo croaker', 'Bobo mullet', 'Boe drum', 'Bogue', 'Bombay-duck',
#        'Bonefish', 'Bonga shad', 'Brazilian codling',
#        'Brazilian flathead', 'Brazilian menhaden', 'Brazilian sardinella',
#        'Brill', 'Brushtooth lizardfish', 'Buccaneer anchovy',
#        'Bullet tuna', 'Burbot', 'Cabinza grunt', 'California pilchard',
#        'Californian anchovy', 'Canary drum(=Baardman)',
#        'Cape bonnetmouth', 'Cape dory', 'Cape elephantfish',
#        'Cape gurnard', 'Cape hakes', 'Cape horse mackerel', 'Capelin',
#        'Carpenter seabream', 'Cassava croaker', 'Castaneta', 'Cero',
#        'Chacunda gizzard shad', 'Chilean jack mackerel',
#        'Chilean silverside', 'Chinese gizzard shad',
#        'Chinook(=Spring=King) salmon', 'Chocolate hind', 'Choicy ruff',
#        'Chola guitarfish', 'Chum(=Keta=Dog) salmon', 'Cobia',
#        'Coho(=Silver) salmon', 'Common dab', 'Common dentex',
#        'Common dolphinfish', 'Common mora', 'Common pandora',
#        'Common silver-biddy', 'Common snook', 'Common sole',
#        'Common warehou', 'Congo dentex', 'Corvina drum', 'Crevalle jack',
#        'Cuckoo ray', 'Cunene horse mackerel', 'Daggertooth pike conger',
#        'Dark ghost shark', 'Demersal fish', 'Demersal fish, discarded',
#        'Devil anglerfish', 'Dogtooth tuna', 'Donkey croaker',
#        'Dorab wolf-herring', 'Dotted gizzard shad', 'Dover sole',
#        'Dusky grouper', 'Dusky smooth-hound', 'Eastern Pacific bonito',
#        'Eelpout', 'Elongate ilisha', 'English sole', 'Eulachon',
#        'European anchovy', 'European conger', 'European eel',
#        'European flounder', 'European hake', 'European perch',
#        'European pilchard(=Sardine)', 'European plaice',
#        'European seabass', 'European smelt', 'European sprat',
#        'European whitefish', 'Falkland sprat', 'False scad',
#        'False trevally', 'Flathead grey mullet', 'Flathead sole',
#        'Florida pompano', 'Forkbeard', 'Fourfinger threadfin',
#        'Freshwater bream', 'Frigate tuna', 'Gag', 'Garfish',
#        'Geelbek croaker', 'Ghost shark', 'Giant African threadfin',
#        'Giant catfish', 'Giant stargazer', 'Giant trevally',
#        'Gilthead seabream', 'Golden grey mullet', 'Golden redfish',
#        'Golden threadfin bream', 'Golden trevally',
#        'Goldstripe sardinella', 'Greasy grouper',
#        'Great Northern tilefish', 'Great barracuda', 'Greater amberjack',
#        'Greater argentine', 'Greater forkbeard', 'Greater lizardfish',
#        'Greater weever', 'Green weakfish', 'Greenback horse mackerel',
#        'Greenland cod', 'Greenland halibut', 'Grey gurnard',
#        'Grey rockcod', 'Guinean striped mojarra', 'Gulf kingcroaker',
#        'Gulf menhaden', 'Gulper shark', 'Gummy shark', 'Haddock',
#        'Haffara seabream', 'Hapuku wreckfish', 'Hilsa shad', 'Hogfish',
#        'Honeycomb grouper', 'Honnibe croaker', 'Humpback grouper',
#        'Humped rockcod', 'Humphead wrasse', 'Indian halibut',
#        'Indian mackerel', 'Indian oil sardine', 'Indian pellona',
#        'Indian scad', 'Indian threadfin', 'Indo-Pacific king mackerel',
#        'Indo-Pacific sailfish', 'Indo-Pacific tarpon', 'Irish mojarra',
#        'Jamaica weakfish', 'Japanese Spanish mackerel',
#        'Japanese anchovy', 'Japanese flyingfish', 'Japanese halfbeak',
#        'Japanese jack mackerel', 'Japanese pilchard', 'Japanese sandfish',
#        'Japanese sardinella', 'Japanese scad', 'Japanese seabass',
#        'Japanese threadfin bream', 'Javelin grunter', 'John dory',
#        "John's snapper", 'Kamchatka flounder', 'Kawakawa',
#        'King mackerel', 'King soldier bream', 'King weakfish', 'Kingklip',
#        "Klunzinger's mullet", 'Korean sandlance', 'Ladyfish',
#        'Lane snapper', 'Large yellow croaker', 'Large-eye dentex',
#        'Largehead hairtail', 'Law croaker', 'Leafscale gulper shark',
#        'Lebranche mullet', 'Leerfish', 'Lemon sole',
#        'Leopard coralgrouper', 'Lesser African threadfin', 'Ling',
#        'Lingcod', 'Little skate', 'Little tunny(=Atl.black skipj)',
#        'Longnose anchovy', 'Longtail Southern cod', 'Longtail tuna',
#        'Lorna drum', 'Lumpfish(=Lumpsucker)', 'Lusitanian cownose ray',
#        'Mackerel icefish', 'Madeiran sardinella', 'Malabar blood snapper',
#        'Mangrove red snapper', 'Masu(=Cherry) salmon', 'Meagre',
#        'Mediterranean horse mackerel', 'Megrim', 'Mi-iuy (brown) croaker',
#        'Milk shark', 'Milkfish', 'Mirror dory', 'Moonfish',
#        'Mote sculpin', 'Mud sole', 'Narrow-barred Spanish mackerel',
#        'Narrownose smooth-hound', 'Nassau grouper', 'Navaga(=Wachna cod)',
#        'New Zealand blue cod', 'New Zealand rough skate',
#        'New Zealand smooth skate', 'North Pacific hake', 'Northern pike',
#        'Northern puffer', 'Northern red snapper', 'Northern wolffish',
#        'Norway pout', 'Nursehound', 'Ocean pout', 'Ocean whitefish',
#        'Oilfish', 'Okhotsk atka mackerel', 'Opah', 'Orange roughy',
#        'Orange-spotted grouper', 'Orangespotted trevally',
#        'Pacific anchoveta', 'Pacific angelshark', 'Pacific bluefin tuna',
#        'Pacific bumper', 'Pacific chub mackerel', 'Pacific cod',
#        'Pacific cornetfish', 'Pacific guitarfish', 'Pacific halibut',
#        'Pacific herring', 'Pacific jack mackerel', 'Pacific menhaden',
#        'Pacific ocean perch', 'Pacific red snapper', 'Pacific rudderfish',
#        'Pacific sandlance', 'Pacific saury', 'Pacific sierra',
#        'Pacific thread herring', 'Panga seabream', 'Parona leatherjacket',
#        'Parore', 'Patagonian blennie', 'Patagonian grenadier',
#        'Patagonian toothfish', 'Pelagic fish', 'Pelagic fish, discarded',
#        'Peruvian banded croaker', 'Peruvian moonfish', 'Peruvian morwong',
#        'Peruvian rock seabass', 'Peruvian weakfish', 'Petrale sole',
#        'Picked dogfish', 'Pike-perch', 'Pink cusk-eel',
#        'Pink ear emperor', 'Pink(=Humpback) salmon', 'Plain bonito',
#        'Plownose chimaera', 'Polar cod', 'Pollack', 'Pontic shad',
#        'Poor cod', 'Porbeagle', 'Portuguese dogfish', 'Pouting(=Bib)',
#        'Rainbow runner', 'Rainbow sardine', 'Rainbow smelt', 'Red bigeye',
#        'Red codling', 'Red cusk-eel', 'Red drum', 'Red grouper',
#        'Red gurnard', 'Red hake', 'Red mullet', 'Red pandora',
#        'Red porgy', 'Red-eye round herring', 'Redfish',
#        'Ridge scaled rattail', 'Roach', 'Rock sole', 'Rough scad',
#        'Roughhead grenadier', 'Round sardinella', 'Roundnose grenadier',
#        'Royal threadfin', 'Rubberlip grunt', 'Rubyfish', 'Ruff',
#        'Sablefish', 'Saddled seabream', 'Saffron cod', 'Saithe(=Pollock)',
#        'Salema', 'Sand sole', 'Sand steenbras', 'Sand weakfish', 'Scup',
#        'Sea trout', 'Senegalese hake', 'Serra Spanish mackerel',
#        'Shallow-water Cape hake', 'Sheepshead', 'Shi drum',
#        'Short mackerel', 'Shortfin mako', 'Shortfin scad',
#        'Shortjaw leatherjacket', 'Shortspine thornyhead', 'Silky shark',
#        'Silver croaker', 'Silver gemfish', 'Silver grunt', 'Silver hake',
#        'Silver pomfret', 'Silver scabbardfish', 'Silver seabream',
#        'Silver sillago', 'Silver warehou', 'Silvery lightfish',
#        'Silvery pout', 'Skipjack tuna', 'Sky emperor',
#        'Small-spotted catshark', 'Smooth weakfish', 'Smooth-hound',
#        'Snoek', 'Snubnose emperor', 'So-iny (redlip) mullet',
#        'So-iuy mullet', 'Sockeye(=Red) salmon', 'Sompat grunt',
#        'South American pilchard', 'South Georgia icefish',
#        'South Pacific hake', 'Southern African anchovy',
#        'Southern blue whiting', 'Southern bluefin tuna', 'Southern hake',
#        'Southern meagre(=Mulloway)', 'Southern rays bream',
#        'Southern red snapper', 'Southern stingray',
#        'Southwest Atlantic butterfish', 'Spangled emperor',
#        'Spot croaker', 'Spotted estuary smooth-hound', 'Spotted ray',
#        'Spotted rose snapper', 'Spotted sardinella', 'Spotted seabass',
#        'Spotted sicklefish', 'Spotted weakfish', 'Spotted wolffish',
#        'Squeteague(=Gray weakfish)', 'Starry ray', 'Striped bass',
#        'Striped bonito', 'Striped marlin', 'Striped piggy',
#        'Striped weakfish', 'Stripped weakfish', 'Summer flounder',
#        'Surmullet', 'Swordfish', 'Tadpole codling', 'Talang queenfish',
#        "Tanaka's snailfish", 'Tarakihi', 'Tarpon', 'Tautog',
#        'Thornback ray', 'Thorntooth grenadier', 'Threadsail filefish',
#        'Three-spined stickleback', 'Tigertooth croaker', 'Toli shad',
#        'Tope shark', 'Torpedo scad', 'Totoaba', 'Tub gurnard', 'Turbot',
#        'Tusk(=Cusk)', 'Twobar seabream', 'Unicorn cod', 'Vadigo',
#        'Velvet leatherjacket', 'Vendace', 'Vermilion snapper', 'Wahoo',
#        'West African Spanish mackerel', 'West African goatfish',
#        'West African ilisha', 'West African ladyfish', 'West coast sole',
#        'Whip stingray', 'White croaker', 'White grouper', 'White grunt',
#        'White hake', 'White mullet', 'White seabream', 'White trevally',
#        'White warehou', 'White weakfish', 'White-blotched grouper',
#        'Whitefin wolf-herring', "Whitehead's round herring",
#        'Whitemouth croaker', 'Whitespotted conger',
#        'Whitespotted wedgefish', 'Whiting', 'Windowpane flounder',
#        'Winter flounder', 'Witch flounder', 'Wreckfish', 'Yellow croaker',
#        'Yellow snapper', 'Yellow striped flounder',
#        'Yellow-edged lyretail', 'Yellowfin seabream', 'Yellowfin sole',
#        'Yellowfin tuna', 'Yellowstripe scad', 'Yellowtail amberjack',
#        'Yellowtail flounder', 'Yellowtail scad', 'Yellowtail snapper'],
#       dtype=object)

# %%
cfs.loc[cfs["location"].isnull(), 'Elem flow name'].unique().tolist()
# Out:
# ['Ammonia',
#  'Nitrogen oxides',
#  'Sulfur dioxide',
#  'Sulfuric acid',
#  'Ammonia, as N',
#  'Ammonium carbonate',
#  'Ammonium nitrate',
#  'Ammonium, ion',
#  'Nitrate',
#  'Nitric oxide',
#  'Nitrite',
#  'Nitrogen dioxide',
#  'Ammonia, Europe',
#  'Ammonia, IAI Area',
#  'Ammonia, IAI Area, Asia',
#  'Nitrogen oxides, Europe',
#  'Nitrogen oxides, IAI Area',
#  'Nitrogen oxides, IAI Area, Asia',
#  'Particulates, < 10 um',
#  'Particulates, < 10 um, Europe',
#  'Particulates, < 10 um, IAI Area',
#  'Particulates, < 10 um, IAI Area, Asia',
#  'Particulates, < 2.5 um',
#  'Particulates, < 2.5 um, Europe',
#  'Particulates, < 2.5 um, IAI Area',
#  'Particulates, < 2.5 um, IAI Area, Asia',
#  'Sulfur dioxide, Europe',
#  'Sulfur dioxide, IAI Area',
#  'Sulfur dioxide, IAI Area, Asia',
#  'Water',
#  'Water, agri',
#  'Water, cooling, unspecified natural origin',
#  'Water, lake',
#  'Water, non-agri',
#  'Water, river',
#  'Water, unspecified natural origin',
#  'Water, well, in ground',
#  'Acoupa weakfish',
#  'African moonfish',
#  'African sicklefish',
#  'Alaska plaice',
#  'Alaska pollock(=Walleye poll.)',
#  'Albacore',
#  'Alewife',
#  'Alexandria pompano',
#  'Alfonsino',
#  'Amer. plaice(=Long rough dab)',
#  'American angler',
#  'American eel',
#  'American shad',
#  'Anchoveta(=Peruvian anchovy)',
#  'Angler(=Monk)',
#  'Angolan dentex',
#  'Annular seabream',
#  'Antarctic toothfish',
#  'Araucanian herring',
#  'Argentine anchovy',
#  'Argentine angelshark',
#  'Argentine conger',
#  'Argentine croaker',
#  'Argentine hake',
#  'Argentine menhaden',
#  'Argentine seabass',
#  'Argentine',
#  'Argentinian sandperch',
#  'Arrowtooth flounder',
#  'Atka mackerel',
#  'Atlantic Spanish mackerel',
#  'Atlantic anchoveta',
#  'Atlantic bluefin tuna',
#  'Atlantic bonito',
#  'Atlantic bumper',
#  'Atlantic butterfish',
#  'Atlantic chub mackerel',
#  'Atlantic cod',
#  'Atlantic croaker',
#  'Atlantic emperor',
#  'Atlantic halibut',
#  'Atlantic herring',
#  'Atlantic horse mackerel',
#  'Atlantic mackerel',
#  'Atlantic menhaden',
#  'Atlantic moonfish',
#  'Atlantic pomfret',
#  'Atlantic sailfish',
#  'Atlantic salmon',
#  'Atlantic saury',
#  'Atlantic silverside',
#  'Atlantic thread herring',
#  'Atlantic tomcod',
#  'Atlantic white marlin',
#  'Atlantic wolffish',
#  'Australian pilchard',
#  'Australian salmon',
#  'Axillary seabream',
#  "Baird's slickhead",
#  'Bali sardinella',
#  'Ballyhoo halfbeak',
#  'Barramundi(=Giant seaperch)',
#  'Barred grunt',
#  'Bartail flathead',
#  'Basking shark',
#  'Bastard halibut',
#  'Beaked redfish',
#  'Bearded brotula',
#  'Benguela hake',
#  'Big-scale sand smelt',
#  'Bigeye grunt',
#  'Bigeye scad',
#  'Bigeye tuna',
#  'Black and Caspian Sea sprat',
#  'Black cardinal fish',
#  'Black cusk-eel',
#  'Black drum',
#  'Black marlin',
#  'Black oreo',
#  'Black pomfret',
#  'Black scabbardfish',
#  'Black seabass',
#  'Black seabream',
#  'Black skipjack',
#  'Black-streaked monocle bream',
#  'Blackbanded trevally',
#  'Blackbelly rosefish',
#  'Blackfin goosefish',
#  'Blackfin icefish',
#  'Blackfin tuna',
#  'Blackhead seabream',
#  'Blackmouth catshark',
#  'Blackmouth croaker',
#  'Blackspot(=red) seabream',
#  'Blackthroat seaperch',
#  'Blacktip shark',
#  'Blonde ray',
#  'Blotched picarel',
#  'Blue butterfish',
#  'Blue grenadier',
#  'Blue jack mackerel',
#  'Blue ling',
#  'Blue mackerel',
#  'Blue marlin',
#  'Blue runner',
#  'Blue shark',
#  'Blue skate',
#  'Blue whiting(=Poutassou)',
#  'Bluefin gurnard',
#  'Bluefish',
#  'Bluenose warehou',
#  'Bluespine unicornfish',
#  'Bluespot mullet',
#  'Boarfish',
#  'Bobo croaker',
#  'Bobo mullet',
#  'Boe drum',
#  'Bogue',
#  'Bombay-duck',
#  'Bonefish',
#  'Bonga shad',
#  'Brazilian codling',
#  'Brazilian flathead',
#  'Brazilian menhaden',
#  'Brazilian sardinella',
#  'Brill',
#  'Brushtooth lizardfish',
#  'Buccaneer anchovy',
#  'Bullet tuna',
#  'Burbot',
#  'Cabinza grunt',
#  'California pilchard',
#  'Californian anchovy',
#  'Canary drum(=Baardman)',
#  'Cape bonnetmouth',
#  'Cape dory',
#  'Cape elephantfish',
#  'Cape gurnard',
#  'Cape hakes',
#  'Cape horse mackerel',
#  'Capelin',
#  'Carpenter seabream',
#  'Cassava croaker',
#  'Castaneta',
#  'Cero',
#  'Chacunda gizzard shad',
#  'Chilean jack mackerel',
#  'Chilean silverside',
#  'Chinese gizzard shad',
#  'Chinook(=Spring=King) salmon',
#  'Chocolate hind',
#  'Choicy ruff',
#  'Chola guitarfish',
#  'Chum(=Keta=Dog) salmon',
#  'Cobia',
#  'Coho(=Silver) salmon',
#  'Common dab',
#  'Common dentex',
#  'Common dolphinfish',
#  'Common mora',
#  'Common pandora',
#  'Common silver-biddy',
#  'Common snook',
#  'Common sole',
#  'Common warehou',
#  'Congo dentex',
#  'Corvina drum',
#  'Crevalle jack',
#  'Cuckoo ray',
#  'Cunene horse mackerel',
#  'Daggertooth pike conger',
#  'Dark ghost shark',
#  'Demersal fish',
#  'Demersal fish, discarded',
#  'Devil anglerfish',
#  'Dogtooth tuna',
#  'Donkey croaker',
#  'Dorab wolf-herring',
#  'Dotted gizzard shad',
#  'Dover sole',
#  'Dusky grouper',
#  'Dusky smooth-hound',
#  'Eastern Pacific bonito',
#  'Eelpout',
#  'Elongate ilisha',
#  'English sole',
#  'Eulachon',
#  'European anchovy',
#  'European conger',
#  'European eel',
#  'European flounder',
#  'European hake',
#  'European perch',
#  'European pilchard(=Sardine)',
#  'European plaice',
#  'European seabass',
#  'European smelt',
#  'European sprat',
#  'European whitefish',
#  'Falkland sprat',
#  'False scad',
#  'False trevally',
#  'Flathead grey mullet',
#  'Flathead sole',
#  'Florida pompano',
#  'Forkbeard',
#  'Fourfinger threadfin',
#  'Freshwater bream',
#  'Frigate tuna',
#  'Gag',
#  'Garfish',
#  'Geelbek croaker',
#  'Ghost shark',
#  'Giant African threadfin',
#  'Giant catfish',
#  'Giant stargazer',
#  'Giant trevally',
#  'Gilthead seabream',
#  'Golden grey mullet',
#  'Golden redfish',
#  'Golden threadfin bream',
#  'Golden trevally',
#  'Goldstripe sardinella',
#  'Greasy grouper',
#  'Great Northern tilefish',
#  'Great barracuda',
#  'Greater amberjack',
#  'Greater argentine',
#  'Greater forkbeard',
#  'Greater lizardfish',
#  'Greater weever',
#  'Green weakfish',
#  'Greenback horse mackerel',
#  'Greenland cod',
#  'Greenland halibut',
#  'Grey gurnard',
#  'Grey rockcod',
#  'Guinean striped mojarra',
#  'Gulf kingcroaker',
#  'Gulf menhaden',
#  'Gulper shark',
#  'Gummy shark',
#  'Haddock',
#  'Haffara seabream',
#  'Hapuku wreckfish',
#  'Hilsa shad',
#  'Hogfish',
#  'Honeycomb grouper',
#  'Honnibe croaker',
#  'Humpback grouper',
#  'Humped rockcod',
#  'Humphead wrasse',
#  'Indian halibut',
#  'Indian mackerel',
#  'Indian oil sardine',
#  'Indian pellona',
#  'Indian scad',
#  'Indian threadfin',
#  'Indo-Pacific king mackerel',
#  'Indo-Pacific sailfish',
#  'Indo-Pacific tarpon',
#  'Irish mojarra',
#  'Jamaica weakfish',
#  'Japanese Spanish mackerel',
#  'Japanese anchovy',
#  'Japanese flyingfish',
#  'Japanese halfbeak',
#  'Japanese jack mackerel',
#  'Japanese pilchard',
#  'Japanese sandfish',
#  'Japanese sardinella',
#  'Japanese scad',
#  'Japanese seabass',
#  'Japanese threadfin bream',
#  'Javelin grunter',
#  'John dory',
#  "John's snapper",
#  'Kamchatka flounder',
#  'Kawakawa',
#  'King mackerel',
#  'King soldier bream',
#  'King weakfish',
#  'Kingklip',
#  "Klunzinger's mullet",
#  'Korean sandlance',
#  'Ladyfish',
#  'Lane snapper',
#  'Large yellow croaker',
#  'Large-eye dentex',
#  'Largehead hairtail',
#  'Law croaker',
#  'Leafscale gulper shark',
#  'Lebranche mullet',
#  'Leerfish',
#  'Lemon sole',
#  'Leopard coralgrouper',
#  'Lesser African threadfin',
#  'Ling',
#  'Lingcod',
#  'Little skate',
#  'Little tunny(=Atl.black skipj)',
#  'Longnose anchovy',
#  'Longtail Southern cod',
#  'Longtail tuna',
#  'Lorna drum',
#  'Lumpfish(=Lumpsucker)',
#  'Lusitanian cownose ray',
#  'Mackerel icefish',
#  'Madeiran sardinella',
#  'Malabar blood snapper',
#  'Mangrove red snapper',
#  'Masu(=Cherry) salmon',
#  'Meagre',
#  'Mediterranean horse mackerel',
#  'Megrim',
#  'Mi-iuy (brown) croaker',
#  'Milk shark',
#  'Milkfish',
#  'Mirror dory',
#  'Moonfish',
#  'Mote sculpin',
#  'Mud sole',
#  'Narrow-barred Spanish mackerel',
#  'Narrownose smooth-hound',
#  'Nassau grouper',
#  'Navaga(=Wachna cod)',
#  'New Zealand blue cod',
#  'New Zealand rough skate',
#  'New Zealand smooth skate',
#  'North Pacific hake',
#  'Northern pike',
#  'Northern puffer',
#  'Northern red snapper',
#  'Northern wolffish',
#  'Norway pout',
#  'Nursehound',
#  'Ocean pout',
#  'Ocean whitefish',
#  'Oilfish',
#  'Okhotsk atka mackerel',
#  'Opah',
#  'Orange roughy',
#  'Orange-spotted grouper',
#  'Orangespotted trevally',
#  'Pacific anchoveta',
#  'Pacific angelshark',
#  'Pacific bluefin tuna',
#  'Pacific bumper',
#  'Pacific chub mackerel',
#  'Pacific cod',
#  'Pacific cornetfish',
#  'Pacific guitarfish',
#  'Pacific halibut',
#  'Pacific herring',
#  'Pacific jack mackerel',
#  'Pacific menhaden',
#  'Pacific ocean perch',
#  'Pacific red snapper',
#  'Pacific rudderfish',
#  'Pacific sandlance',
#  'Pacific saury',
#  'Pacific sierra',
#  'Pacific thread herring',
#  'Panga seabream',
#  'Parona leatherjacket',
#  'Parore',
#  'Patagonian blennie',
#  'Patagonian grenadier',
#  'Patagonian toothfish',
#  'Pelagic fish',
#  'Pelagic fish, discarded',
#  'Peruvian banded croaker',
#  'Peruvian moonfish',
#  'Peruvian morwong',
#  'Peruvian rock seabass',
#  'Peruvian weakfish',
#  'Petrale sole',
#  'Picked dogfish',
#  'Pike-perch',
#  'Pink cusk-eel',
#  'Pink ear emperor',
#  'Pink(=Humpback) salmon',
#  'Plain bonito',
#  'Plownose chimaera',
#  'Polar cod',
#  'Pollack',
#  'Pontic shad',
#  'Poor cod',
#  'Porbeagle',
#  'Portuguese dogfish',
#  'Pouting(=Bib)',
#  'Rainbow runner',
#  'Rainbow sardine',
#  'Rainbow smelt',
#  'Red bigeye',
#  'Red codling',
#  'Red cusk-eel',
#  'Red drum',
#  'Red grouper',
#  'Red gurnard',
#  'Red hake',
#  'Red mullet',
#  'Red pandora',
#  'Red porgy',
#  'Red-eye round herring',
#  'Redfish',
#  'Ridge scaled rattail',
#  'Roach',
#  'Rock sole',
#  'Rough scad',
#  'Roughhead grenadier',
#  'Round sardinella',
#  'Roundnose grenadier',
#  'Royal threadfin',
#  'Rubberlip grunt',
#  'Rubyfish',
#  'Ruff',
#  'Sablefish',
#  'Saddled seabream',
#  'Saffron cod',
#  'Saithe(=Pollock)',
#  'Salema',
#  'Sand sole',
#  'Sand steenbras',
#  'Sand weakfish',
#  'Scup',
#  'Sea trout',
#  'Senegalese hake',
#  'Serra Spanish mackerel',
#  'Shallow-water Cape hake',
#  'Sheepshead',
#  'Shi drum',
#  'Short mackerel',
#  'Shortfin mako',
#  'Shortfin scad',
#  'Shortjaw leatherjacket',
#  'Shortspine thornyhead',
#  'Silky shark',
#  'Silver croaker',
#  'Silver gemfish',
#  'Silver grunt',
#  'Silver hake',
#  'Silver pomfret',
#  'Silver scabbardfish',
#  'Silver seabream',
#  'Silver sillago',
#  'Silver warehou',
#  'Silvery lightfish',
#  'Silvery pout',
#  'Skipjack tuna',
#  'Sky emperor',
#  'Small-spotted catshark',
#  'Smooth weakfish',
#  'Smooth-hound',
#  'Snoek',
#  'Snubnose emperor',
#  'So-iny (redlip) mullet',
#  'So-iuy mullet',
#  'Sockeye(=Red) salmon',
#  'Sompat grunt',
#  'South American pilchard',
#  'South Georgia icefish',
#  'South Pacific hake',
#  'Southern African anchovy',
#  'Southern blue whiting',
#  'Southern bluefin tuna',
#  'Southern hake',
#  'Southern meagre(=Mulloway)',
#  'Southern rays bream',
#  'Southern red snapper',
#  'Southern stingray',
#  'Southwest Atlantic butterfish',
#  'Spangled emperor',
#  'Spot croaker',
#  'Spotted estuary smooth-hound',
#  'Spotted ray',
#  'Spotted rose snapper',
#  'Spotted sardinella',
#  'Spotted seabass',
#  'Spotted sicklefish',
#  'Spotted weakfish',
#  'Spotted wolffish',
#  'Squeteague(=Gray weakfish)',
#  'Starry ray',
#  'Striped bass',
#  'Striped bonito',
#  'Striped marlin',
#  'Striped piggy',
#  'Striped weakfish',
#  'Stripped weakfish',
#  'Summer flounder',
#  'Surmullet',
#  'Swordfish',
#  'Tadpole codling',
#  'Talang queenfish',
#  "Tanaka's snailfish",
#  'Tarakihi',
#  'Tarpon',
#  'Tautog',
#  'Thornback ray',
#  'Thorntooth grenadier',
#  'Threadsail filefish',
#  'Three-spined stickleback',
#  'Tigertooth croaker',
#  'Toli shad',
#  'Tope shark',
#  'Torpedo scad',
#  'Totoaba',
#  'Tub gurnard',
#  'Turbot',
#  'Tusk(=Cusk)',
#  'Twobar seabream',
#  'Unicorn cod',
#  'Vadigo',
#  'Velvet leatherjacket',
#  'Vendace',
#  'Vermilion snapper',
#  'Wahoo',
#  'West African Spanish mackerel',
#  'West African goatfish',
#  'West African ilisha',
#  'West African ladyfish',
#  'West coast sole',
#  'Whip stingray',
#  'White croaker',
#  'White grouper',
#  'White grunt',
#  'White hake',
#  'White mullet',
#  'White seabream',
#  'White trevally',
#  'White warehou',
#  'White weakfish',
#  'White-blotched grouper',
#  'Whitefin wolf-herring',
#  "Whitehead's round herring",
#  'Whitemouth croaker',
#  'Whitespotted conger',
#  'Whitespotted wedgefish',
#  'Whiting',
#  'Windowpane flounder',
#  'Winter flounder',
#  'Witch flounder',
#  'Wreckfish',
#  'Yellow croaker',
#  'Yellow snapper',
#  'Yellow striped flounder',
#  'Yellow-edged lyretail',
#  'Yellowfin seabream',
#  'Yellowfin sole',
#  'Yellowfin tuna',
#  'Yellowstripe scad',
#  'Yellowtail amberjack',
#  'Yellowtail flounder',
#  'Yellowtail scad',
#  'Yellowtail snapper']

# %%
cfs = cfs.loc[~cfs["location"].isnull()]

# %%
# Load IW <-> ecoinvent mapping
ei_map = pd.read_excel("ei_iw_mapping.xlsx")

# %%
# Define the order of versions from highest to lowest priority
version_order = ["3.10", "3.9", "3.8", "3.7.1", "3.7", "3.6", "3.5 or earlier"]

# Convert the column to categorical with the defined order
ei_map["introduced in ei v."] = pd.Categorical(ei_map["introduced in ei v."], categories=version_order, ordered=True)

# Sort the dataframe so that the highest version appears first
ei_map = ei_map.sort_values(by="introduced in ei v.", ascending=False)

# Create the dictionary by preserving the first encountered mapping
mapping_dict = {}
for _, row in ei_map.iterrows():
    is_name = row["iw name"]
    ecoinvent_name = row["ecoinvent name"]
    if is_name not in mapping_dict:  # Only add if it's not already mapped
        mapping_dict[is_name] = ecoinvent_name

# %%
mapping_dict
# Out:
# {'1,3-Dioxolan-2-one': '1,3-Dioxolan-2-one',
#  'Phthalate, butyl-benzyl-': 'Phthalate, butyl-benzyl-',
#  'Pirimicarb': 'Pirimicarb',
#  'Piperonyl butoxide': 'Piperonyl butoxide',
#  'Pinoxaden': 'Pinoxaden',
#  'Picoxystrobin': 'Picoxystrobin',
#  'Picloram': 'Picloram',
#  'Phthalate, dioctyl-': 'Phthalate, dioctyl-',
#  'Phthalate, dimethyl-': 'Phthalate, dimethyl-',
#  'Phthalate, dibutyl-': 'Phthalate, dibutyl-',
#  'Phosphorus': 'Phosphorus, 18% in apatite, 4% in crude ore, in ground',
#  'Benzene, 1-methyl-2-nitro-': 'o-Nitrotoluene',
#  nan: 'Phosphorus trichloride',
#  'Phosphoric acid': 'Phosphoric acid',
#  'Phosphate': 'Phosphate',
#  'Pirimiphos methyl': 'Pirimiphos methyl',
#  'Platinum': 'Platinum',
#  'Profenofos': 'Profenofos',
#  'Procymidone': 'Procymidone',
#  'Prochloraz': 'Prochloraz',
#  'Praseodymium': 'Praseodymium, 0.42% in bastnasite, 0.042% in crude ore, in ground',
#  'Fatty acids, c9-13-neo-': 'Potassium soap',
#  'Potassium chloride': 'Potassium chloride',
#  'Potassium': 'Potassium',
#  'Polychlorinated biphenyls': 'Polychlorinated biphenyls',
#  'Polonium-210': 'Polonium-210',
#  'Plutonium-alpha': 'Plutonium-alpha',
#  'Plutonium-238': 'Plutonium-238',
#  'Phosmet': 'Phosmet',
#  'Phosgene': 'Phosgene',
#  'Phosalone': 'Phosalone',
#  'Particulates, > 10 um': 'Particulates, > 10 um',
#  'Parathion': 'Parathion',
#  'Paraquat': 'Paraquat',
#  'o-Xylene': 'o-Xylene',
#  'Oxyfluorfen': 'Oxyfluorfen',
#  'Oxydemeton methyl': 'Oxydemeton-methyl',
#  'Oxasulfuron': 'Oxasulfuron',
#  'Oxamyl': 'Oxamyl',
#  'Oxadixyl': 'Oxadixyl',
#  'Oryzalin': 'Oryzalin',
#  'Particulates, < 2.5 um': 'Particulates, < 2.5 um',
#  'Particulates, > 2.5 um, and < 10um': 'Particulates, > 2.5 um, and < 10um',
#  'Phorate': 'Phorate',
#  'Phenol, pentachloro-': 'Phenol, pentachloro-',
#  'Phenol, 2,4-dichloro-': 'Phenol, 2,4-dichloro',
#  'Phenol': 'Phenol',
#  'Phenmedipham': 'Phenmedipham',
#  'Phenanthrene': 'Phenanthrene',
#  'Pethoxamid': 'Pethoxamid',
#  'Permethrin': 'Permethrin',
#  'Perlite': 'Perlite, in ground',
#  'Pentane, perfluoro-': 'Perfluoropentane',
#  'Pentane': 'Pentane',
#  'Pendimethalin': 'Pendimethalin',
#  'Pencycuron': 'Pencycuron',
#  'Penconazole': 'Penconazole',
#  'Peat': 'Peat, in ground',
#  'Prometryn': 'Prometryn',
#  'Pronamide': 'Pronamide',
#  'Radon-222': 'Radon-222',
#  'Radium-226': 'Radium-226',
#  'Cesium-137': 'Radioactive species, other beta emitters',
#  'Uranium-238': 'Radioactive species, Nuclides, unspecified',
#  'Antimony-124': 'Radioactive species, from fission and activation',
#  'Tetrachlorvinphos ((Z)-isomer)': 'Rabon',
#  'Quizalofop ethyl ester': 'Quizalofop-p-ethyl',
#  'Benzene, pentachloronitro-': 'Quintozene',
#  'Quinoxyfen': 'Quinoxyfen',
#  'Quinmerac': 'Quinmerac',
#  'Quinclorac': 'Quinclorac',
#  'Pyrithiobac sodium salt': 'Pyrithiobac sodium salt',
#  'Sethoxydim': 'Sethoxydim',
#  'Selenium': 'Selenium',
#  'Scandium': 'Scandium',
#  'Sand': 'Sand, unspecified, in ground',
#  'Samarium': 'Samarium, 0.3% in bastnasite, 0.03% in crude ore, in ground',
#  'Ruthenium-106': 'Ruthenium-106',
#  'Rubidium': 'Rubidium',
#  'Rotenone': 'Rotenone',
#  'Rimsulfuron': 'Rimsulfuron',
#  'Rhenium': 'Rhenium, in crude ore, in ground',
#  'Pyrolusite': 'Pyrolusite, in ground',
#  'Pyrite': 'Pyrite, in ground',
#  'Propachlor': 'Propachlor',
#  'Prosulfocarb': 'Prosulfocarb',
#  'Propylene oxide': 'Propylene oxide',
#  'Propylamine': 'Propylamine',
#  'Propionic acid': 'Propionic acid',
#  'Propineb': 'Propineb',
#  'Propiconazole': 'Propiconazole',
#  'Propham': 'Propham',
#  'Propene': 'Propene',
#  'Propargite': 'Propargite',
#  'Propaquizafop': 'Propaquizafop',
#  '1-Propanol': 'Propanol',
#  'Propanil': 'Propanil',
#  'Propane': 'Propane',
#  'Propanal': 'Propanal',
#  'Propamocarb hcl': 'Propamocarb HCl',
#  'Propamocarb HCl': 'Propamocarb HCl',
#  'Propamocarb': 'Propamocarb',
#  'Proquinazid': 'Proquinazid',
#  'Prosulfuron': 'Prosulfuron',
#  'Pyriproxyfen': 'Pyriproxyfen',
#  'Pyrimethanil': 'Pyrimethanil',
#  'Pyrifenox': 'Pyrifenox',
#  'Pyridate': 'Pyridate',
#  'Pyrethrum': 'Pyrethrum',
#  'Pyrethrin': 'Pyrethrin',
#  'Pyrene': 'Pyrene',
#  'Pyrazophos': 'Pyrazophos',
#  'Pyraflufen-ethyl': 'Pyraflufen-ethyl',
#  'Pyraclostrobin': 'Pyraclostrobin',
#  'Pymetrozine': 'Pymetrozine',
#  'Pumice': 'Pumice, in ground',
#  'P-tert-amylphenol': 'P-tert-amylphenol',
#  'Orbencarb': 'Orbencarb',
#  'Olivine': 'Olivine, in ground',
#  'Siduron': 'Siduron',
#  'Molybdenum': 'Molybdenum, 0.014% in sulfide, Mo 8.2E-3% and Cu 0.81% in crude ore, in ground',
#  'Ethane, chloro-': 'Monochloroethane',
#  '1,4-Butanediol': '1,4-Butanediol',
#  'Molinate': 'Molinate',
#  'Mevinfos': 'Mevinfos',
#  'Metsulfuron-methyl': 'Metsulfuron-methyl',
#  'Metribuzin': 'Metribuzin',
#  'Metosulam': 'Metosulam',
#  'Metolachlor': 'Metolachlor',
#  'Monocrotophos': 'Monocrotophos',
#  'Monoethanolamine': 'Monoethanolamine',
#  'Monolinuron': 'Monolinuron',
#  'Nickel': 'Nickel, 1.13% in sulfide, Ni 0.76% and Cu 0.76% in crude ore, in ground',
#  'Neodymium': 'Neodymium, 4% in bastnasite, 0.4% in crude ore, in ground',
#  'Neburon': 'Neburon',
#  'Napropamide': 'Napropamide',
#  'Naphthalene': 'Naphthalene',
#  'Naled': 'Naled',
#  'Myclobutanil': 'Myclobutanil',
#  'm-Xylene': 'm-Xylene',
#  'Monosodium acid methanearsonate': 'MSMA',
#  'Metobromuron': 'Metobromuron',
#  'Metiram': 'Metiram',
#  'Methylamine': 'Methylamine',
#  'Methane, biogenic': 'Methane, non-fossil',
#  'Methane, fossil': 'Methane, from soil or biomass stock',
#  'Methane, difluoro-, HFC-32': 'Methane, difluoro-, HFC-32',
#  'Methane, dichlorofluoro-, HCFC-21': 'Methane, dichlorofluoro-, HCFC-21',
#  'Methane, dichlorodifluoro-, CFC-12': 'Methane, dichlorodifluoro-, CFC-12',
#  'Methane, dichloro-, HCC-30': 'Methane, dichloro-, HCC-30',
#  'Methane, chlorotrifluoro-, CFC-13': 'Methane, chlorotrifluoro-, CFC-13',
#  'Methane, chlorofluoro-, HCFC-31': 'Methane, chloro-fluoro-, HCFC-31',
#  'Methane, chlorodifluoro-, HCFC-22': 'Methane, chlorodifluoro-, HCFC-22',
#  'Methane, bromotrifluoro-, Halon 1301': 'Methane, bromotrifluoro-, Halon 1301',
#  'Methane, bromochlorodifluoro-, Halon 1211': 'Methane, bromochlorodifluoro-, Halon 1211',
#  'Methane, bromo-, Halon 1001': 'Methane, bromo-, Halon 1001',
#  'Methamidophos': 'Methamidophos',
#  'Methabenzthiazuron': 'Methabenzthiazuron',
#  'Metconazole': 'Metconazole',
#  'Metazachlor': 'Metazachlor',
#  'Methane, monochloro-, R-40': 'Methane, monochloro-, R-40',
#  'Methane, tetrachloro-, CFC-10': 'Methane, tetrachloro-, R-10',
#  'Methane, tetrafluoro-, CFC-14': 'Methane, tetrafluoro-, R-14',
#  'Parathion, methyl': 'Methyl parathion',
#  'Methyl lactate': 'Methyl lactate',
#  'Methyl formate': 'Methyl formate',
#  'Methyl ethyl ketone': 'Methyl ethyl ketone',
#  'Trimethyl borate': 'Methyl borate',
#  'Methyl acrylate': 'Methyl acrylate',
#  'Methyl acetate': 'Methyl acetate',
#  'Methoxyfenozide': 'Methoxyfenozide',
#  'Methoprene': 'Methoprene',
#  'Methomyl': 'Methomyl',
#  'Methiocarb': 'Methiocarb',
#  'Methidathion': 'Methidathion',
#  'Methanol': 'Methanol',
#  'Methanesulfonic acid': 'Methanesulfonic acid',
#  'Methane, trifluoro-, HFC-23': 'Methane, trifluoro-, HFC-23',
#  'Methane, trichlorofluoro-, CFC-11': 'Methane, trichlorofluoro-, CFC-11',
#  'Nickel(II)': 'Nickel, ion',
#  'Occupation, forest/grassland, not used': 'Occupation, seabed, natural (non-use)',
#  'Occupation, unspecified': 'Occupation, river, artificial',
#  'Occupation, permanent crops': 'Occupation, permanent crop, non-irrigated, intensive',
#  'Occupation, pasture/meadow': 'Occupation, pasture, man made, intensive',
#  'Occupation, artificial areas': 'Occupation, mineral extraction site',
#  'Occupation, agriculture, mosaic (agroforestry)': 'Occupation, heterogeneous, agricultural',
#  'Occupation, secondary vegetation': 'Occupation, shrub land, sclerophyllous',
#  'Oil, crude': 'Oil, crude, in ground',
#  'Benzene, 1,2-dichloro-': 'o-Dichlorobenzene',
#  'Octanoic acid': 'Octanoic acid',
#  'Occupation, annual crops': 'Occupation, annual crop, irrigated',
#  'Novaluron': 'Novaluron',
#  'Norflurazon': 'Norflurazon',
#  'NMVOC, non-methane volatile organic compounds, unspecified origin': 'NMVOC, non-methane volatile organic compounds, unspecified origin',
#  'Nitrothal-isopropyl': 'Nitrothal-isopropyl',
#  'Nitrogen, organic bound': 'Nitrogen, organic bound',
#  'Nitrogen oxides': 'Nitrogen oxides',
#  'Nitrogen fluoride': 'Nitrogen fluoride',
#  'Nitrogen': 'Nitrogen',
#  'Nitrobenzene': 'Nitrobenzene',
#  'Nitrite': 'Nitrite',
#  'Nitric oxide': 'Nitric oxide',
#  'Nitrate': 'Nitrate',
#  'Nicosulfuron': 'Nicosulfuron',
#  'Occupation, forest, used': 'Occupation, forest, unspecified',
#  'Shale': 'Shale, in ground',
#  'Silicon': 'Silicon',
#  'Metamorphous rock, graphite containing': 'Metamorphous rock, graphite containing, in ground',
#  'Transformation, to pasture/meadow': 'Transformation, to pasture, man made, intensive',
#  'Transformation, to unspecified': 'Transformation, to river, artificial',
#  'Transformation, to permanent crops': 'Transformation, to permanent crop, non-irrigated, intensive',
#  'Transformation, from permanent crops': 'Transformation, from permanent crop, non-irrigated, intensive',
#  'Transformation, to artificial areas': 'Transformation, to mineral extraction site',
#  'Transformation, to forest/grassland, not used': 'Transformation, to lake, natural (non-use)',
#  'Transformation, to agriculture, mosaic (agroforestry)': 'Transformation, to heterogeneous, agricultural',
#  'Triasulfuron': 'Triasulfuron',
#  'Triallate': 'Tri-allate',
#  'Triadimenol': 'Triadimenol',
#  'Transformation, to secondary vegetation': 'Transformation, to shrub land, sclerophyllous',
#  'Transformation, to forest, used': 'Transformation, to forest, unspecified',
#  'Transformation, to annual crops': 'Transformation, to annual crop',
#  'Transformation, from forest/grassland, not used': 'Transformation, from wetland, coastal (non-use)',
#  'Transformation, from artificial areas': 'Transformation, from urban/industrial fallow (non-use)',
#  'Transformation, from unspecified': 'Transformation, from unspecified',
#  'Transformation, from secondary vegetation': 'Transformation, from shrub land, sclerophyllous',
#  'Triazamate': 'Triazamate',
#  'Tribenuron-methyl': 'Tribenuron',
#  'Xenon-133': 'Xenon-133',
#  'Wood, unspecified, standing/m3': 'Wood, unspecified, standing',
#  'Wood, soft, standing': 'Wood, soft, standing',
#  'Wood, hard, standing': 'Wood, primary forest, standing',
#  'Water, well, in ground': 'Water, well, in ground',
#  'Water, unspecified natural origin': 'Water, unspecified natural origin',
#  'Water, cooling, unspecified natural origin': 'Water, turbine use, unspecified natural origin',
#  'Water, river': 'Water, river',
#  'Water, lake': 'Water, lake',
#  'Water': 'Water',
#  'Xylene': 'Xylene',
#  'Zoxamide': 'Zoxamide',
#  'Zirconium': 'Zirconium, in ground',
#  'Baddeleyite': 'Zirconia, as baddeleyite, in ground',
#  'Ziram': 'Ziram',
#  'Zineb': 'Zineb',
#  'Zinc': 'Zinc, Zn 3.1%, in mixed ore, in ground',
#  'Zinc(II)': 'Zinc, ion',
#  'Alpha-cypermethrin': 'Zeta-cypermethrin',
#  'Tribufos': 'Tribufos',
#  'Triticonazole': 'Triticonazole',
#  'Trinexapac-ethyl': 'Trinexapac-ethyl',
#  'Trimethylamine': 'Trimethylamine',
#  'Triforine': 'Triforine',
#  'Triflusulfuron-methyl': 'Triflusulfuron-methyl',
#  'Trifluralin': 'Trifluralin',
#  'Triflumuron': 'Triflumuron',
#  'Triflumizole': 'Triflumizole',
#  'Trifloxystrobin': 'Trifloxystrobin',
#  'Triethylene glycol': 'Triethylene glycol',
#  'Tridemorph': 'Tridemorph',
#  'Triclopyr': 'Triclopyr',
#  'Ethene, trichloro-': 'Trichloroethylene',
#  'Trichlorfon': 'Trichlorfon',
#  'Tributyltin oxide': 'Tributyltin compounds',
#  'Tungsten': 'Tungsten',
#  'Ulexite': 'Ulexite, in ground',
#  'Vinclozolin': 'Vinclozolin',
#  'Vermiculite': 'Vermiculite, in ground',
#  'Vanadium(V)': 'Vanadium, ion',
#  'Vanadium': 'Vanadium',
#  'Vamidothion': 'Vamidothion',
#  'Urea': 'Urea',
#  'Uranium-235': 'Uranium-235',
#  'Uranium-234': 'Uranium-234',
#  'Uranium': 'Uranium, in ground',
#  'Sulfate': 'Sulfate, ion',
#  'Sulfur dioxide': 'Sulfur dioxide',
#  'Sulfur': 'Sulfur',
#  'Sulfotep': 'Sulfotep',
#  'Sulfosulfuron': 'Sulfosulfuron',
#  'Sulfentrazone': 'Sulfentrazone',
#  'Sulcotrione': 'Sulcotrione',
#  'Styrene': 'Styrene',
#  'Strontium-90': 'Strontium-90',
#  'Strontium': 'strontium, in ground',
#  'Stibnite': 'Stibnite, in ground',
#  'Sulfur hexafluoride': 'Sulfur hexafluoride',
#  'Sulfur trioxide': 'Sulfur trioxide',
#  'Teflubenzuron': 'Teflubenzuron',
#  'Tebupirimphos': 'Tebupirimphos',
#  'Tebufenpyrad': 'Tebufenpyrad',
#  'Tebufenozide': 'Tebufenozide',
#  'Tebuconazole': 'Tebuconazole',
#  'Thiazole, 2-(thiocyanatemethylthio)benzo-': 'TCMTB',
#  't-Butylamine': 't-Butylamine',
#  't-Butyl methyl ether': 't-Butyl methyl ether',
#  'Tau-fluvalinate': 'tau-Fluvalinate',
#  'Tantalum': 'Tantalum, 81.9% in tantalite, 1.6E-4% in crude ore, in ground',
#  'Talc': 'Talc, in ground',
#  'Sulfuric acid': 'Sulfuric acid',
#  'Starane': 'Starane',
#  'Spodumene': 'Spodumene, in ground',
#  'Spiroxamine': 'Spiroxamine',
#  'Silver-110': 'Silver-110',
#  'Silver': 'Silver, in ground',
#  'Silthiofam': 'Silthiofam',
#  'Silver(I)': 'Silver, ion',
#  'Simazine': 'Simazine',
#  'Spirodiclofen': 'Spirodiclofen',
#  'Metolachlor, (S)': 'S-metolachlor',
#  'Sodium sulfate': 'Sodium sulphate, various forms, in ground',
#  'Sodium nitrate': 'Sodium nitrate, in ground',
#  'Sodium formate': 'Sodium formate',
#  'Sodium chloride': 'Sodium chloride, in ground',
#  'Salt, unspecified': 'Sodium chloride, in ground',
#  'Tefluthrin': 'Tefluthrin',
#  'Tellurium': 'Tellurium',
#  'Transformation, from forest, used': 'Transformation, from forest, extensive',
#  'Transformation, from annual crops': 'Transformation, from arable land, unspecified use',
#  'Transformation, from pasture/meadow': 'Transformation, from pasture, man made, intensive',
#  'Transformation, from agriculture, mosaic (agroforestry)': 'Transformation, from heterogeneous, agricultural',
#  'Tralomethrin': 'Tralomethrin',
#  'Tolyfluanide': 'Tolylfluanid',
#  'Thiodicarb': 'Thiodicarb',
#  'Thiocyanic acid (-1 ion)': 'Thiocyanate, ion',
#  'Thiobencarb': 'Thiobencarb',
#  'Thifensulfuron-methyl': 'Thifensulfuron-methyl',
#  'Thidiazuron': 'Thidiazuron',
#  'Thiamethoxam': 'Thiamethoxam',
#  'Thiacloprid': 'Thiacloprid',
#  'Thiabendazole': 'Thiabendazole',
#  'Thallium': 'Thallium',
#  'Alpha-pinene': 'Terpenes',
#  'Terbutryn': 'Terbutryn',
#  'Terbuthylazin': 'Terbuthylazin',
#  'Terbufos': 'Terbufos',
#  'Terbacil': 'Terbacil',
#  'Tepraloxydim': 'Tepraloxydim',
#  'N,N-Dimethyl-1,2,3-trithian-5-amine': 'Thiocyclam',
#  'Thiophanate-methyl': 'Thiophanat-methyl',
#  'Toluene, 2-chloro-': 'Toluene, 2-chloro',
#  'Thiram': 'Thiram',
#  'Toluene': 'Toluene',
#  'Tin(II)': 'Tin, ion',
#  'Tin': 'Tin, in ground',
#  'Thorium-230': 'Thorium-230',
#  'Thorium': 'Thorium',
#  'Metam-sodium dihydrate': 'Metam-sodium',
#  'Metamitron': 'Metamitron',
#  'Chlorosulfonic acid': 'Chlorosulfonic acid',
#  'Choline chloride': 'Choline chloride',
#  'ethyl 3-(3,5-dichlorophenyl)-5-methyl-2,4-dioxo-1,3-oxazolidine-5-carboxylate': 'Chlozolinate',
#  'Chlorthal': 'Chlorthal',
#  'Chlorsulfuron': 'Chlorsulfuron',
#  'Chlorpyrifos methyl': 'Chlorpyrifos methyl',
#  'Chlorpyrifos': 'Chlorpyrifos',
#  'Chlortoluron': 'Chlorotoluron',
#  'Chlorothalonil': 'Chlorothalonil',
#  'Chlorotrimethylsilane': 'Chlorosilane, trimethyl-',
#  'Chloropicrin': 'Chloropicrin',
#  'Chloroform': 'Chloroform',
#  'Chloroacetyl chloride': 'Chloroacetyl chloride',
#  'Chloroacetic acid': 'Chloroacetic acid',
#  'Chlormequat chloride': 'Chlormequat chloride',
#  'Chlormequat': 'Chlormequat',
#  'Trichloroethane': 'Chlorinated solvents, unspecified',
#  'Chromium': 'Chromium',
#  'Chromium(III)': 'Chromium IV',
#  'Chromium(VI)': 'Chromium VI',
#  'Clothianidin': 'Clothianidin',
#  'Cloransulam-methyl': 'Cloransulam-methyl',
#  'Cloquintocet-mexyl': 'Cloquintocet-mexyl',
#  'Clopyralid': 'Clopyralid',
#  'Clomazone': 'Clomazone',
#  'Clofentezine': 'Clofentezine',
#  'Clodinafop-propargyl': 'Clodinafop-propargyl',
#  'Clethodim': 'Clethodim',
#  'Clay, unspecified': 'Clay, unspecified, in ground',
#  'Clay, bentonite': 'Clay, bentonite, in ground',
#  'Cinnabar': 'Cinnabar, in ground',
#  'Chrysotile': 'Chrysotile, in ground',
#  'Chrysene': 'Chrysene',
#  'Chlorimuron-ethyl': 'Chlorimuron-ethyl',
#  'Carbonyl sulfide': 'Carbonyl sulfide',
#  'Carbon-14': 'Carbon-14',
#  'Carbon monoxide, biogenic': 'Carbon monoxide, non-fossil',
#  'Carbon monoxide, fossil': 'Carbon monoxide, from soil or biomass stock',
#  'Carbon disulfide': 'Carbon disulfide',
#  'Carbon dioxide, to soil or biomass stock': 'Carbon dioxide, to soil or biomass stock',
#  'Carbon dioxide, biogenic, release': 'Carbon dioxide, non-fossil',
#  'Carbon dioxide, biogenic, uptake': 'Carbon dioxide, in air',
#  'Carbon dioxide, fossil': 'Carbon dioxide, from soil or biomass stock',
#  'Carbon': 'Carbon',
#  'Carbofuran': 'Carbofuran',
#  'Carbetamide': 'Carbetamide',
#  'Carbendazim': 'Carbendazim',
#  'Carbaryl': 'Carbaryl',
#  'Captan': 'Captan',
#  'Carbamic acid, [(dibutylamino)thio]methyl-, 2,3-': 'Carbosulfan',
#  'Carboxin': 'Carboxin',
#  'Chloridazon': 'Chloridazon',
#  'Chlorfenvinphos': 'Chlorfenvinphos',
#  'Chlorbufam': 'Chlorbufam',
#  'Chlorbromuron': 'Chlorbromuron',
#  'Chloramine': 'Chloramine',
#  'Cesium-134': 'Cesium-134',
#  'Cesium': 'Cesium',
#  'Carfentrazone-ethyl': 'Carfentrazone-ethyl',
#  'Coal, brown': 'Coal, brown, in ground',
#  'Coal, hard': 'Coal, hard, unspecified, in ground',
#  'Cobalt': 'Cobalt',
#  'Dibutyltin oxide': 'Dibutyltin',
#  'Dibenz(a,h)anthracene': 'Dibenz(a,h)anthracene',
#  'Diazinon': 'Diazinon',
#  'Diatomite': 'Diatomite, in ground',
#  'Dialifor': 'Dialifor',
#  'Diafenthiuron': 'Diafenthiuron',
#  'Desmedipham': 'Desmedipham',
#  'Demeton-s-methyl': 'Demeton-S-methylsulfon',
#  'Deltamethrin': 'Deltamethrin',
#  'Decanoic acid': 'Decanoic acid',
#  'Dazomet': 'Dazomet',
#  'Daminozide': 'Daminozide',
#  'Cyromazine': 'Cyromazine',
#  'Cyprodinil': 'Cyprodinil',
#  'Cyproconazole': 'Cyproconazole',
#  'Cypermethrin': 'Cypermethrin',
#  'Cymoxanil': 'Cymoxanil',
#  'Cyhexatin': 'Cyhexatin',
#  'Dicamba': 'Dicamba',
#  'Cyhalothrin': 'Cyhalothrin',
#  'Dichlobenil': 'Dichlobenil',
#  'Difenoconazole': 'Difenoconazole',
#  'Diethylene glycol': 'Diethylene glycol',
#  'Diethylamine': 'Diethylamine',
#  'Diethyl ether': 'Diethyl ether',
#  'Carbamic acid, (3,4-diethoxyphenyl)-, 1-methylet': 'Diethofencarb',
#  'Diethanolamine': 'Diethanolamine',
#  'Dienochlor': 'Dienochlor',
#  'Dicrotophos': 'Dicrotophos',
#  'Dicofol': 'Dicofol',
#  'Diclofop-methyl': 'Diclofop-methyl',
#  'Dichlorvos': 'Dichlorvos',
#  'Dichlorprop-P': 'Dichlorprop-P',
#  'Dichlorprop': 'Dichlorprop',
#  'Dimethyldichlorosilane': 'Dichlorodimethylsilane',
#  'Dichlofluanid': 'Dichlofluanid',
#  'Cyfluthrin': 'Cyfluthrin',
#  'Copper': 'Copper, Cu 6.8E-1%, in mixed ore, in ground',
#  'Colemanite': 'Colemanite, in ground',
#  'COD': 'COD, Chemical Oxygen Demand',
#  'Cobalt-60': 'Cobalt-60',
#  'Cobalt-58': 'Cobalt-58',
#  'Copper(II)': 'Copper, ion',
#  'Cycloxydim': 'Cycloxydim',
#  'Cyclopentane': 'Cyclopentane',
#  'Cyclohexane': 'Cyclohexane (for all cycloalkanes)',
#  'Cyclanilide': 'Cyclanilide',
#  'Cyazofamid': 'Cyazofamid',
#  'Cyanoacetic acid': 'Cyanoacetic acid',
#  'Metaldehyde (tetramer)': 'Metaldehyde',
#  'Cyanazine': 'Cyanazine',
#  'Cyanamide': 'Cyanamide',
#  'Curium-alpha': 'Curium alpha',
#  'Cumene': 'Cumene',
#  'Calcium cyanamide': 'Calcium cyanamide',
#  'Diflufenican': 'Diflufenican',
#  'Allyl chloride': 'Allyl chloride',
#  'Amidosulfuron': 'Amidosulfuron',
#  'Ametryn': 'Ametryn',
#  'Americium-241': 'Americium-241',
#  'Aluminium': 'Aluminium, in ground',
#  'Bauxite': 'Aluminium, 24% in bauxite, 11% in crude ore, in ground',
#  'Allethrin': 'Allethrin',
#  'Aldrin': 'Aldrin',
#  'Aldicarb': 'Aldicarb',
#  'Aldehydes, unspecified': 'Aldehydes, unspecified',
#  'Alanycarb': 'Alanycarb',
#  'Alachlor': 'Alachlor',
#  'Acrylonitrile': 'Acrylonitrile',
#  'N,N-Dimethyldodecylamine oxide': 'Amine oxide',
#  'Amitraz': 'Amitraz',
#  'Ammonia': 'Ammonia',
#  'Ammonium carbonate': 'Ammonium carbonate',
#  'Arsenic(III)': 'Arsenic, ion',
#  'Arsenic': 'Arsenic',
#  'Antimony-125': 'Antimony-125',
#  'Antimony': 'Antimony',
#  'Anthraquinone': 'Anthraquinone',
#  'Anthranilic acid': 'Anthranilic acid',
#  'Anthracene': 'Anthracene',
#  'Aniline': 'Aniline',
#  'Anilazine': 'Anilazine',
#  'Anhydrite': 'Anhydrite, in ground',
#  'Ammonium, ion': 'Ammonium, ion',
#  'Acrylic acid': 'Acrylic acid',
#  'Acrolein': 'Acrolein',
#  '4-Methyl-2-pentanol': '4-Methyl-2-pentanol',
#  '2-Propanol': '2-Propanol',
#  '2-Phenylphenol': '2-Phenylphenol',
#  '4-Nitrobenzoic acid': '2-Nitrobenzoic acid',
#  '2-Butene, 2-methyl-': '2-Methyl-2-butene',
#  '2-Methyl-1-propanol': '2-Methyl-1-propanol',
#  'Pentane, 2-methyl-': '2-Methyl pentane',
#  '2-Chlorobenzaldehyde': '2-chlorobenzaldehyde',
#  '1-Amino-2-propanol': '2-Aminopropanol',
#  '2-Amino-3-chloro-1,4-naphthoquinone': '2-Amino-3-chloro-1,4-naphthoquinone',
#  '2,4-Di-tert-butylphenol': '2,4-di-tert-butylphenol',
#  'Butyric acid, 4-(2,4-dichlorophenoxy)-': '2,4-DB',
#  '2,4-D butyl ester': '2,4-D ester',
#  '2,4-D, dimethylamine salt': '2,4-D amines',
#  '2,4-D': '2,4-D',
#  '2,2,4-Trimethylpentane': '2,2,4-Trimethyl pentane',
#  '1-Pentene': '1-Pentene',
#  '1-Pentanol': '1-Pentanol',
#  '3-Methyl-1-butanol': '3-Methyl-1-butanol',
#  '4-Methyl-2-pentanone': '4-Methyl-2-pentanone',
#  'Acrinathrin': 'Acrinathrin',
#  '8-Quinolinol': '8-Quinolinol',
#  'Aclonifen': 'Aclonifen',
#  'Acifluorfen': 'Acifluorfen',
#  'Acibenzolar-s-methyl': 'Acibenzolar-S-methyl',
#  'Acetyl chloride': 'Acetyl chloride',
#  'Acetonitrile': 'Acetonitrile',
#  'Acetone': 'Acetone',
#  'Acetochlor': 'Acetochlor',
#  '2,2,2-TRIFLUOROETHANOL': 'Acetic acid, trifluoro-',
#  'Acetic acid': 'Acetic acid',
#  'Acetamiprid': 'Acetamiprid',
#  'Acetamide': 'Acetamide',
#  'Acetaldehyde': 'Acetaldehyde',
#  'Acephate': 'Acephate',
#  'Acenaphthylene': 'Acenaphthylene',
#  'Acenaphthene': 'Acenaphthene',
#  'Arsine': 'Arsine',
#  'Asulam': 'Asulam',
#  'Atrazine': 'Atrazine',
#  'Bromoxynil': 'Bromoxynil',
#  '1-Bromopropane': 'Bromopropane',
#  'Bromofenoxim': 'Bromofenoxim',
#  'Bromacil': 'Bromacil',
#  'Boscalid': 'Boscalid',
#  'Boron carbide': 'Boron carbide',
#  'Boron': 'Boron',
#  'Crude natural boric acid': 'Boric acid',
#  'BOD': 'BOD5, Biological Oxygen Demand',
#  'Bitertanol': 'Bitertanol',
#  'Bisphenol A': 'Bisphenol A',
#  "Isopropyl 4,4'dibromobenzilate": 'Bromopropylate',
#  'Bromoxynil octanoate': 'Bromoxynil octanoate',
#  'Bifenox': 'Bifenox',
#  'Bromuconazole': 'Bromuconazole',
#  'Calcite': 'Calcite, in ground',
#  'Cadmium(II)': 'Cadmium, ion',
#  'Cadmium': 'Cadmium, 0.30% in sulfide, Cd 0.18%, Pb, Zn, Ag, In, in ground',
#  'Butyrolactone': 'Butyrolactone',
#  'Carbamic acid, butyl-, 3-iodo-2-propynyl ester': 'Butylcarbamate, iodopropynyl',
#  'Butyl acetate': 'Butyl acetate',
#  'Butralin': 'Butralin',
#  'Butoxycarboxim': 'Butoxycarboxim',
#  '1-Butene': 'Butene',
#  '1-Butanol': 'Butanol',
#  'Butane': 'Butane',
#  'Butafenacil': 'Butafenacil',
#  'Butadiene': 'Butadiene',
#  'Buprofezin': 'Buprofezin',
#  'Bupirimate': 'Bupirimate',
#  'Bifenthrin': 'Bifenthrin',
#  'Azaconazol': 'Azaconazol',
#  'Bensultap': 'Bensultap',
#  'Bensulfuron methyl ester': 'Bensulfuron methyl ester',
#  'Benoxacor': 'Benoxacor',
#  'Benomyl': 'Benomyl',
#  'Benfluralin': 'Benfluralin',
#  'Benazolin': 'Benazolin',
#  'Benalaxyl': 'Benalaxyl',
#  'Basalt': 'Basalt, in ground',
#  'Barium': 'Barium',
#  'Barite': 'Barite, 15% in crude ore, in ground',
#  'Azoxystrobin': 'Azoxystrobin',
#  'Aziprotryne': 'Aziprotryne',
#  'Azinphos-methyl': 'Azinphos-methyl',
#  'Azadirachtin': 'Azadirachtin',
#  'Bentazone': 'Bentazone',
#  'Benthiavalicarb-isopropyl': 'Benthiavalicarb-isopropyl',
#  'Beta-cypermethrin isomer': 'Beta-cypermethrin',
#  'Benzo(a)anthracene': 'Benz(a)anthracene',
#  'Beryllium': 'Beryllium',
#  'Benzyl alcohol': 'Benzyl alcohol',
#  'Benzthiazuron': 'Benzthiazuron',
#  'Benzoximate': 'Benzoximate',
#  'Benzoic acid': 'Benzoic acid',
#  'Benzo(k)fluoranthene': 'Benzo(k)fluoranthene',
#  'Benzo(g,h,i)perylene': 'Benzo(ghi)perylene',
#  'Benzo(b)fluoranthene': 'Benzo(b)fluoranthene',
#  'Benzo(a)pyrene': 'Benzo(a)pyrene',
#  'Benzene, pentachloro-': 'Benzene, pentachloro-',
#  'Benzene, hexachloro-': 'Benzene, hexachloro-',
#  'Benzene, ethyl-': 'Benzene, ethyl-',
#  'Benzene, chloro-': 'Benzene, chloro-',
#  'Benzene': 'Benzene',
#  'Benzaldehyde': 'Benzaldehyde',
#  'Diflubenzuron': 'Diflubenzuron',
#  'Diflufenzopyr-sodium': 'Diflufenzopyr-sodium',
#  'Hydrocarbons, aromatic': 'Hydrocarbons, aromatic',
#  'Hydrocarbons, chlorinated': 'Hydrocarbons, chlorinated',
#  'Furfural': 'Furfural',
#  'Diisobutyl ketone': 'Diisobutyl ketone',
#  'Hydrocarbons, aliphatic, alkanes, cyclic': 'Hydrocarbons, aliphatic, alkanes, cyclic',
#  'Hydrazine': 'Hydrazine',
#  'Hydramethylnon': 'Hydramethylnon',
#  'Hexythiazox': 'Hexythiazox',
#  'Hexazinone': 'Hexazinone',
#  'Hexane': 'Hexane',
#  'Hexamethyldisilazane': 'Hexamethyldisilizane',
#  'Hydrogen-3, Tritium': 'Hydrogen-3, Tritium',
#  'Hymexazol': 'Hymexazol',
#  'Iodine-133': 'Iodine-133',
#  'Iodine-131': 'Iodine-131',
#  'Iodine-129': 'Iodine-129',
#  'Indoxacarb': 'Indoxacarb',
#  'Indium': 'Indium, 0.005% in sulfide, In 0.003%, Pb, Zn, Ag, Cd, in ground',
#  'Indeno(1,2,3-cd)pyrene': 'Indeno(1,2,3-cd)pyrene',
#  'Imidacloprid': 'Imidacloprid',
#  'Imazethapyr': 'Imazethapyr',
#  'Imazaquin': 'Imazaquin',
#  'Imazapyr': 'Imazapyr',
#  'Imazamox': 'Imazamox',
#  'Imazalil': 'Imazalil',
#  'Hexaflumuron': 'Hexaflumuron',
#  'Hexaconazole': 'Hexaconazole',
#  'Gold': 'Gold, Au 4.3E-4%, in ore, in ground',
#  'Glyphosate': 'Glyphosate',
#  'Glutaraldehyde': 'Glutaraldehyde',
#  'Glufosinate ammonium': 'Glufosinate ammonium',
#  'Gas, natural/m3': 'Gas, natural, in ground',
#  'Gallium': 'Gallium, in ground',
#  'Heptenophos': 'Heptenophos',
#  'Heptane': 'Heptane',
#  'Helium': 'Helium, 0.08% in natural gas, in ground',
#  'Halosulfuron-methyl': 'Halosulfuron-methyl',
#  'Gypsum': 'Gypsum, in ground',
#  "Guanidine, N,N'''-(iminodi-8,1-octanediyl)bis-": 'Guazatine',
#  'Gravel': 'Gravel, in ground',
#  'Granite': 'Granite, in ground',
#  'Iodosulfuron-methyl-sodium': 'Iodosulfuron-methyl-sodium',
#  'Manganese': 'Manganese',
#  'Mandipropamid': 'Mandipropamid',
#  'Mancozeb': 'Mancozeb',
#  'Maleic hydrazide': 'Maleic hydrazide',
#  'Maleic anhydride': 'Maleic anhydride',
#  'Malathion': 'Malathion',
#  'Magnesium': 'Magnesium, in ground',
#  'Magnesite': 'Magnesite, 60% in crude ore, in ground',
#  'Lufenuron': 'Lufenuron',
#  'Lithium': 'Lithium, 0.15% in brine, in ground',
#  'Linuron': 'Linuron',
#  'Lindane': 'Lindane',
#  'Maneb': 'Maneb',
#  'Lead-210': 'Lead-210',
#  'Manganese-54': 'Manganese-54',
#  'Metalaxyl-M': 'Metalaxyl-M',
#  'Metalaxil': 'Metalaxil',
#  'Mesotrione': 'Mesotrione',
#  'Mercury': 'Mercury',
#  'Mepronil': 'Mepronil',
#  'Mepiquat chloride': 'Mepiquat chloride',
#  'Mepanipyrim': 'Mepanipyrim',
#  'Mefenpyr-diethyl': 'Mefenpyr-diethyl',
#  'Mecoprop-p': 'Mecoprop-P',
#  'Mecoprop-P': 'Mecoprop-P',
#  '2-(4-Chloro-2-methylphenoxy)propanoic acid': 'Mecoprop',
#  'MCPB': 'MCPB',
#  '2-Methyl-4-chlorophenoxyacetic acid': 'MCPA',
#  'Lenacil': 'Lenacil',
#  'Lead': 'Lead, Pb 3.6E-1%, in mixed ore, in ground',
#  'Ioxynil': 'Ioxynil',
#  'Kieserite': 'Kieserite, 25% in crude ore, in ground',
#  'Isoxaflutole': 'Isoxaflutole',
#  'Isoxadifen-ethyl': 'Isoxadifen-ethyl',
#  'Isoproturon': 'Isoproturon',
#  'Isopropylamine': 'Isopropylamine',
#  'Isoprene': 'Isoprene',
#  'Isobutane': 'Isobutane',
#  'Iron(III)': 'Iron, ion',
#  'Iron': 'Iron, in ground',
#  'Iprovalicarb': 'Iprovalicarb',
#  'Iprodione': 'Iprodion',
#  'Kaolinite': 'Kaolinite, 24% in crude ore, in ground',
#  'Kresoxim-methyl': 'Kresoxim-methyl',
#  'Dodecanoic acid': 'Lauric acid',
#  'Lanthanum': 'Lanthanum, 7.2% in bastnasite, 0.72% in crude ore, in ground',
#  'Lambda-cyhalothrin': 'Lambda-cyhalothrin',
#  'Lactofen': 'Lactofen',
#  'Lactic acid': 'Lactic acid',
#  'Krypton-85': 'Krypton-85',
#  'Gadolinium': 'Gadolinium, 0.15% in bastnasite, 0.015% in crude ore, in ground',
#  'Ethane, 1,1-dichloro-1-fluoro-, HCFC-141b': 'Ethane, 1,1-dichloro-1-fluoro-, HCFC-141b',
#  'Ethane, 1,1,2-trichloro-': 'Ethane, 1,1,2-trichloro-',
#  'Ethane, 1,1,1-trifluoro-, HFC-143a': 'Ethane, 1,1,1-trifluoro-, HFC-143a',
#  'Ethane, 1,1,1-trichloro-, HCFC-140': 'Ethane, 1,1,1-trichloro-, HCFC-140',
#  'Ethane, 1,1,1,2-tetrafluoro-, HFC-134a': 'Ethane, 1,1,1,2-tetrafluoro-, HFC-134a',
#  'Ethane thiol': 'Ethane thiol',
#  'Ethane': 'Ethane',
#  'Ethalfluralin': 'Ethalfluralin',
#  'Esfenvalerate': 'Esfenvalerate',
#  'Dipropylthiocarbamic acid S-ethyl ester': 'EPTC',
#  'Epoxiconazole': 'Epoxiconazole',
#  'Epichlorohydrin': 'Epichlorohydrin',
#  'Ethane, 1,1,2-trichloro-1,2,2-trifluoro-, CFC-113': 'Ethane, 1,1,2-trichloro-1,2,2-trifluoro-, CFC-113',
#  'Ethane, 1,1-difluoro-, HFC-152a': 'Ethane, 1,1-difluoro-, HFC-152a',
#  'Endosulfan': 'Endosulfan',
#  'Ethane, 1,2-dichloro-': 'Ethane, 1,2-dichloro-',
#  'Ethoprop': 'Ethoprop',
#  'Ethofumesate': 'Ethofumesate',
#  'Ethiofencarb': 'Ethiofencarb',
#  'Ethephon': 'Ethephon',
#  'Ethene, tetrachloro-': 'Ethene, tetrachloro-',
#  'Ethene, chloro-': 'Ethene, chloro-',
#  'Ethene': 'Ethene',
#  'Ethanol': 'Ethanol',
#  'Ethane, pentafluoro-, HFC-125': 'Ethane, pentafluoro-, HFC-125',
#  'Ethane, hexafluoro-, HFC-116': 'Ethane, hexafluoro-, HFC-116',
#  'Ethane, hexachloro-': 'Ethane, hexachloro-',
#  'Ethane, chloropentafluoro-, CFC-115': 'Ethane, chloropentafluoro-, CFC-115',
#  'Ethane, 2-chloro-1,1,1,2-tetrafluoro-, HCFC-124': 'Ethane, 2-chloro-1,1,1,2-tetrafluoro-, HCFC-124',
#  'Ethane, 2,2-dichloro-1,1,1-trifluoro-, HCFC-123': 'Ethane, 2,2-dichloro-1,1,1-trifluoro-, HCFC-123',
#  'Ethane, 1-chloro-1,1-difluoro-, HCFC-142b': 'Ethane, 1-chloro-1,1-difluoro-, HCFC-142b',
#  'Ethane, 1,2-dichloro-1,1,2,2-tetrafluoro-, CFC-114': 'Ethane, 1,2-dichloro-1,1,2,2-tetrafluoro-, CFC-114',
#  'Endothall': 'Endothall',
#  'Dinocap': 'Dinocap',
#  'Dinitrogen monoxide': 'Dinitrogen monoxide',
#  'Dimethylamine': 'Dimethylamine',
#  'Dimethyl malonate': 'Dimethyl malonate',
#  'Dimethyl ether': 'Dimethyl ether',
#  'Dimethyl carbonate': 'Dimethyl carbonate',
#  'Dimethomorph': 'Dimethomorph',
#  'Dimethoate': 'Dimethoate',
#  'Dimethipin': 'Dimethipin',
#  'Dimethenamid': 'Dimethenamid-P',
#  'Dimethachlor': 'Dimethachlor',
#  'Dinoseb': 'Dinoseb',
#  'Dioxin, 2,3,7,8 Tetrachlorodibenzo-p-': 'Dioxins, measured as 2,3,7,8-tetrachlorodibenzo-p-dioxin',
#  'Disodium acid methane arsenate': 'DSMA',
#  'Diphenyl ether': 'Diphenylether-compound',
#  'Dolomite': 'Dolomite, in ground',
#  'Dodine': 'Dodine',
#  'Dodemorph': 'Dodemorph',
#  'Dodecanol': 'Dodecanol',
#  'DNOC': 'DNOC',
#  'Furan': 'Furan',
#  'Dithianone': 'Dithianon',
#  'Disulfoton': 'Disulfoton',
#  'Pelagic fish, discarded': 'Discarded fish, pelagic, to ocean',
#  'Demersal fish, discarded': 'Discarded fish, demersal, to ocean',
#  'Diquat dibromide': 'Diquat dibromide',
#  'Diquat': 'Diquat',
#  'Dipropylamine': 'Dipropylamine',
#  'Ethyl acetate': 'Ethyl acetate',
#  'Diuron': 'Diuron',
#  'Ethylamine': 'Ethylamine',
#  'Flurochloridone': 'Flurochloridone',
#  'Fluquinconazole': 'Fluquinconazole',
#  'Fluorspar': 'Fluorspar, 92%, in ground',
#  'Fluorine': 'Fluorine, 4.5% in apatite, 3% in crude ore, in ground',
#  'Fluorene': 'Fluorene',
#  'Fluoranthene': 'Fluoranthene',
#  'Fluometuron': 'Fluometuron',
#  'Flumioxazin': 'Flumioxazin',
#  'Flumiclorac-pentyl': 'Flumiclorac-pentyl',
#  'Fluroxypyr': 'Fluroxypyr',
#  'Fludioxonil': 'Fludioxonil',
#  'Flurtamone': 'Flurtamone',
#  'Furalaxyl': 'Furalaxyl',
#  'Fuberidazole': 'Fuberidazole',
#  'Fosetyl-aluminium': 'Fosetyl-aluminium',
#  'Formic acid': 'Formic acid',
#  'Formamide': 'Formamide',
#  'Formaldehyde': 'Formaldehyde',
#  'Foramsulfuron': 'Foramsulfuron',
#  'Fonofos': 'Fonofos',
#  'Fomesafen': 'Fomesafen',
#  'Folpet': 'Folpet',
#  'Flutolanil': 'Flutolanil',
#  'Flusilazole': 'Flusilazole',
#  'Flumetsulam': 'Flumetsulam',
#  'Flufenacet': 'Flufenacet',
#  'Flucarbazone-sodium': 'Flucarbazone sodium salt',
#  'Fenoxaprop ethyl ester': 'Fenoxaprop ethyl ester',
#  'Fenhexamid': 'Fenhexamid',
#  'Fenfuram': 'Fenfuram',
#  'Fenbutatin oxide': 'Fenbutatin oxide',
#  'Fenbuconazole': 'Fenbuconazole',
#  'Fenazaquin': 'Fenazaquin',
#  'Fenamiphos': 'Fenamiphos',
#  'Fenamidone': 'Fenamidone',
#  'Feldspar': 'Feldspar, in ground',
#  'Famoxadone': 'Famoxadone',
#  'Europium': 'Europium, 0.06% in bastnasite, 0.006% in crude ore, in ground',
#  'Etridiazole': 'Etridiazole',
#  'Etoxazole': 'Etoxazole',
#  'Ethyne': 'Ethyne',
#  'Ethylene oxide': 'Ethylene oxide',
#  'Ethanol, 2-ethoxy-': 'Ethylene glycol monoethyl ether',
#  'Ethylene diamine': 'Ethylene diamine',
#  'Fenitrothion': 'Fenitrothion',
#  'Fenoxaprop': 'Fenoxaprop',
#  'Fenoxaprop-P ethyl ester': 'Fenoxaprop-P ethyl ester',
#  'Fipronil': 'Fipronil',
#  'Fluazinam': 'Fluazinam',
#  'Fluazifop-p-butyl': 'Fluazifop-P-butyl',
#  'Fluazifop-P-butyl': 'Fluazifop-P-butyl',
#  'Fluazifop': 'Fluazifop',
#  'Florasulam': 'Florasulam',
#  'Flazasulfuron': 'Flazasulfuron',
#  'Demersal fish': 'Fish, demersal, in ocean',
#  'Pelagic fish': 'Fish, pelagic, in ocean',
#  'Fentin hydroxide': 'Fentin hydroxide',
#  'Fentin acetate': 'Fentin acetate',
#  'Fenpyroximate': 'Fenpyroximate',
#  'cis-4-[3-(p-tert-butylphenyl)-2-methylpropyl]-2,6-dimethylmorpholine': 'Fenpropimorph',
#  'Fenpropidin': 'Fenpropidin',
#  'Fenpropathrin': 'Fenpropathrin',
#  'Fenpiclonil': 'Fenpiclonil',
#  'Fenoxycarb': 'Fenoxycarb',
#  'Energy, unspecified': 'Exported energy - heat',
#  'Benzene, 1-methyl-3-nitro-': 'm-Nitrotoluene',
#  'Peracetic acid': 'Peracetic acid',
#  'Dimethyl formamide': 'N,N-Dimethylformamide',
#  'Methylcyclohexane': 'Methylcyclohexane',
#  'Hydrogen cyanide': 'Hydrogen cyanide',
#  '4-nitrotoluene': 'p-Nitrotoluene',
#  'Tert-butylhydroperoxide': 'Tert-butyl hydroperoxide',
#  'Trifluoroacetic acid': 'Trifluoroacetic acid',
#  't-Butyl alcohol': 'Tert-butanol',
#  'Strontium(II)': 'Strontium II',
#  'Methanol, sodium salt': 'Sodium methoxide',
#  'Chloroacetic acid, sodium salt': 'Sodium chloroacetate',
#  'gamma-Cyhalothrin': 'Gamma-cyhalothrin',
#  'Acetic anhydride': 'Acetic anhydride',
#  '2-Methyl-2-butanol': '2-Methyl-2-butanol',
#  'Phenol, 2-chloro-': '2-Chlorophenol',
#  'Toluene, 2,4-diamine': '2,4-Diaminotoluene',
#  'Propene, 1,3-dichloro-': '1,3-Dichloropropene',
#  'Cesium(I)': 'Caesium I',
#  'Phthalate, n-dioctyl-': 'Dioctyl phthalate',
#  'Bismuth': 'Bismuth, in ground',
#  'Germanium': 'Germanium, in ground',
#  'Niobium': 'Niobium, in ground',
#  'Nitric acid': 'Nitric acid',
#  'Nitrogen dioxide': 'Nitrogen dioxide',
#  'Yttrium': 'Yttrium, in ground',
#  'Benzovindiflupyr': 'Benzovindiflupyr',
#  'Chlorantraniliprole': 'Chlorantraniliprole',
#  'Chlorfenapyr': 'Chlorfenapyr',
#  'Diflufenzopyr': 'Diflufenzopyr',
#  'Ethaboxam': 'Ethaboxam',
#  'Fluxapyroxad': 'Fluxapyroxad',
#  '1-Methyl-2-pyrrolidinone': 'N-methyl-2-pyrrolidone',
#  'Saflufenacil': 'Saflufenacil',
#  'Sedaxane': 'Sedaxane',
#  'Triclopyr triethylammonium salt': 'Triethylammonium',
#  'Alkylbenzene (c10-c15)': 'Alkylbenzene (c10-c15)',
#  'Aluminium(III)': 'Aluminium III',
#  'Antimony(III)': 'Antimony ion',
#  'Barium(II)': 'Barium II',
#  'Beryllium(II)': 'Beryllium II',
#  'Bifenazate': 'Bifenazate',
#  'Cobalt(II)': 'Cobalt II',
#  'EDTA': 'EDTA, Ethylenediaminetetraacetic Acid',
#  'Flonicamid': 'Flonicamid',
#  'Flubendiamide': 'Flubendiamide',
#  'Fluopyram': 'Fluopyram',
#  'Flupyradifurone': 'Flupyradifurone',
#  'Fluthiacet-methyl': 'Fluthiacet-methyl',
#  'Flutriafol': 'Flutriafol',
#  'Gibberellic acid': 'Gibberellic acid',
#  'Hafnium': 'Hafnium',
#  'Haloxyfop-ethoxyethyl': 'Haloxyfop-ethoxyethyl',
#  'Lead(II)': 'Lead II',
#  'Lutetium': 'Lutetium',
#  'Manganese(II)': 'Manganese II',
#  'Mercury(II)': 'Mercury II',
#  'Molybdenum(VI)': 'Molybdenum VI',
#  'Propylene glycol': 'Propylene glycol',
#  'Prothioconazole': 'Prothioconazole',
#  'Selenium(IV)': 'Selenium IV',
#  'Spinetoram J': 'Spinetoram J',
#  'Spiromesifen': 'Spiromesifen',
#  'Spirotetramat': 'Spirotetramat',
#  'Sulfadiazine': 'Sulfadiazine',
#  'Tebuthiuron': 'Tebuthiuron',
#  'Tembotrione': 'Tembotrione',
#  'Tetraconazole': 'Tetraconazole',
#  'Thallium(I)': 'Thallium I',
#  'Thiencarbazone-methyl': 'Thiencarbazone-methyl',
#  'Tolfenpyrad': 'Tolfenpyrad',
#  'Topramezone': 'Topramezone',
#  'Particulates, < 10 um': 'Particulate Matter, > 2.5 um and < 10um'}

# %%
# create a column called `ecoinvent_name` where we map the `Elem flow name` to ecoinvent names
cfs["ecoinvent_name"] = cfs["Elem flow name"].map(mapping_dict)

# %%
cfs.head()
# Out:
#       Unnamed: 0           Impact category    CF unit Compartment  \
# 3050        3050  Freshwater acidification  kg SO2 eq         Air
# 3051        3051  Freshwater acidification  kg SO2 eq         Air
# 3052        3052  Freshwater acidification  kg SO2 eq         Air
# 3053        3053  Freshwater acidification  kg SO2 eq         Air
# 3054        3054  Freshwater acidification  kg SO2 eq         Air
#
#                  Sub-compartment Elem flow name CAS number  CF value  \
# 3050               (unspecified)        Ammonia  7664-41-7  0.180141
# 3051                  high. pop.        Ammonia  7664-41-7  0.180141
# 3052                   low. pop.        Ammonia  7664-41-7  0.180141
# 3053  stratosphere + troposphere        Ammonia  7664-41-7  0.180141
# 3054                      indoor        Ammonia  7664-41-7  0.180141
#
#      Elem flow unit MP or Damage Native geographical resolution scale  \
# 3050             kg     Midpoint                              Country
# 3051             kg     Midpoint                              Country
# 3052             kg     Midpoint                              Country
# 3053             kg     Midpoint                              Country
# 3054             kg     Midpoint                              Country
#
#      location ecoinvent_name
# 3050       AD        Ammonia
# 3051       AD        Ammonia
# 3052       AD        Ammonia
# 3053       AD        Ammonia
# 3054       AD        Ammonia

# %%
# we drop unmapped flows
print(cfs.loc[cfs["ecoinvent_name"].isna(), "Elem flow name"].unique())
cfs = cfs.dropna(subset=["ecoinvent_name"])
# Out:
# ['Ammonia, as N' 'Ammonium nitrate' 'Phosphorus pentoxide' 'HNO3'
#  'Water, agri' 'Water, non-agri']

# %%
print(cfs.loc[~cfs["ecoinvent_name"].isna(), "Elem flow name"].unique())
# Out:
# ['Ammonia' 'Ammonium carbonate' 'Ammonium, ion' 'Nitrate' 'Nitric oxide'
#  'Nitrite' 'Nitrogen dioxide' 'Nitrogen oxides' 'Sulfate' 'Sulfur dioxide'
#  'Sulfur trioxide' 'Sulfuric acid' 'BOD' 'COD' 'Phosphate'
#  'Phosphoric acid' 'Phosphorus'
#  'Occupation, agriculture, mosaic (agroforestry)'
#  'Occupation, annual crops' 'Occupation, artificial areas'
#  'Occupation, forest, used' 'Occupation, pasture/meadow'
#  'Occupation, permanent crops' 'Occupation, secondary vegetation'
#  'Occupation, unspecified'
#  'Transformation, from agriculture, mosaic (agroforestry)'
#  'Transformation, from annual crops'
#  'Transformation, from artificial areas'
#  'Transformation, from forest, used' 'Transformation, from pasture/meadow'
#  'Transformation, from permanent crops'
#  'Transformation, from secondary vegetation'
#  'Transformation, from unspecified'
#  'Transformation, to agriculture, mosaic (agroforestry)'
#  'Transformation, to annual crops' 'Transformation, to artificial areas'
#  'Transformation, to forest, used' 'Transformation, to pasture/meadow'
#  'Transformation, to permanent crops'
#  'Transformation, to secondary vegetation'
#  'Transformation, to unspecified' 'Nitric acid' 'Particulates, < 10 um'
#  'Particulates, < 2.5 um' 'Water'
#  'Water, cooling, unspecified natural origin' 'Water, lake' 'Water, river'
#  'Water, unspecified natural origin' 'Water, well, in ground']

# %%
# create a `ecoinvent main compartment` column, and map the
# `Compartment` column to ecoinvent main compartments
# using the main_comp dictionary

main_comp = {"Air": "air", "Raw": "natural resource", "Soil": "soil", "Water": "water"}
cfs["ecoinvent_main_compartment"] = cfs["Compartment"].map(main_comp)

print(cfs.loc[cfs["ecoinvent_main_compartment"].isna(), "Compartment"].unique())
# Out:
# []

# %%
# create a `ecoinvent sub compartment` column, and map the
# `Sub-compartment` column to ecoinvent main compartments
# using the sub_comp dictionary

sub_comp = {
    "(unspecified)": "unspecified",
    "agricultural": "agricultural",
    "biotic": "biotic",
    "groundwater": "ground-",
    "groundwater, long-term": "ground-, long-term",
    "high. pop.": "urban air close to ground",
    "in air": "in air",
    "in ground": "in ground",
    "in water": "in water",
    "indoor": "indoor",
    "industrial": "industrial",
    "lake": "surface water",
    "land": "land",
    "low. pop.": "non-urban air or from high stacks",
    "low. pop., long-term": "low population density, long-term",
    "ocean": "ocean",
    "river": "surface water",
    "stratosphere + troposphere": "lower stratosphere + upper troposphere"
}

cfs["ecoinvent_sub_compartment"] = cfs["Sub-compartment"].map(sub_comp)
print(cfs.loc[cfs["ecoinvent_sub_compartment"].isna(), "Sub-compartment"].unique())
# Out:
# []

# %%
cfs.head()
# Out:
#       Unnamed: 0           Impact category    CF unit Compartment  \
# 3050        3050  Freshwater acidification  kg SO2 eq         Air
# 3051        3051  Freshwater acidification  kg SO2 eq         Air
# 3052        3052  Freshwater acidification  kg SO2 eq         Air
# 3053        3053  Freshwater acidification  kg SO2 eq         Air
# 3054        3054  Freshwater acidification  kg SO2 eq         Air
#
#                  Sub-compartment Elem flow name CAS number  CF value  \
# 3050               (unspecified)        Ammonia  7664-41-7  0.180141
# 3051                  high. pop.        Ammonia  7664-41-7  0.180141
# 3052                   low. pop.        Ammonia  7664-41-7  0.180141
# 3053  stratosphere + troposphere        Ammonia  7664-41-7  0.180141
# 3054                      indoor        Ammonia  7664-41-7  0.180141
#
#      Elem flow unit MP or Damage Native geographical resolution scale  \
# 3050             kg     Midpoint                              Country
# 3051             kg     Midpoint                              Country
# 3052             kg     Midpoint                              Country
# 3053             kg     Midpoint                              Country
# 3054             kg     Midpoint                              Country
#
#      location ecoinvent_name ecoinvent_main_compartment  \
# 3050       AD        Ammonia                        air
# 3051       AD        Ammonia                        air
# 3052       AD        Ammonia                        air
# 3053       AD        Ammonia                        air
# 3054       AD        Ammonia                        air
#
#                    ecoinvent_sub_compartment
# 3050                             unspecified
# 3051               urban air close to ground
# 3052       non-urban air or from high stacks
# 3053  lower stratosphere + upper troposphere
# 3054                                  indoor

# %%
import copy
cfs_data = {}
for c, category in enumerate(cfs["Impact category"].unique()):
    for t, impact_type in enumerate(cfs["MP or Damage"].unique()):
        subset = cfs.loc[
            (cfs["Impact category"] == category)
            & (cfs["MP or Damage"] == impact_type)
        ]

        cfs_data[f"{category}_{impact_type.lower()}"] = []

        # iterate through rows
        for _, row in subset.iterrows():
            if row["CF value"] != 0:
                data = {
                    "supplier": {
                        "name": row["ecoinvent_name"],
                        "categories": [row["ecoinvent_main_compartment"], row["ecoinvent_sub_compartment"]] if row["ecoinvent_sub_compartment"] != "unspecified" else [row["ecoinvent_main_compartment"]],
                        "matrix": "biosphere"
                    },
                    "consumer": {
                        "location": row["location"],
                        "matrix": "technosphere"
                    },
                    "value": row["CF value"]
                }
                if data not in cfs_data[f"{category}_{impact_type.lower()}"]:
                    cfs_data[f"{category}_{impact_type.lower()}"].append(data)

# %%
# save each category as a separate json file
import json

for category in cfs_data:
    with open(f"/Users/romain/GitHub/edges/edges/data/ImpactWorld+ 2.1_{category}.json", "w") as f:
        print(f"Saving {category}")
        json.dump(
            cfs_data[category],
            f,
            indent=2
        )
# Out:
# Saving Freshwater acidification_midpoint
# Saving Freshwater acidification_damage
# Saving Freshwater ecotoxicity_midpoint
# Saving Freshwater ecotoxicity_damage
# Saving Freshwater eutrophication_midpoint
# Saving Freshwater eutrophication_damage
# Saving Land occupation, biodiversity_midpoint
# Saving Land occupation, biodiversity_damage
# Saving Land transformation, biodiversity_midpoint
# Saving Land transformation, biodiversity_damage
# Saving Marine eutrophication_midpoint
# Saving Marine eutrophication_damage
# Saving Particulate matter formation_midpoint
# Saving Particulate matter formation_damage
# Saving Photochemical ozone formation_midpoint
# Saving Photochemical ozone formation_damage
# Saving Terrestrial acidification_midpoint
# Saving Terrestrial acidification_damage
# Saving Water scarcity_midpoint
# Saving Water scarcity_damage
# Saving Photochemical ozone formation, human health_midpoint
# Saving Photochemical ozone formation, human health_damage
# Saving Water availability, human health_midpoint
# Saving Water availability, human health_damage
# Saving Freshwater ecotoxicity, long term_midpoint
# Saving Freshwater ecotoxicity, long term_damage
# Saving Freshwater ecotoxicity, short term_midpoint
# Saving Freshwater ecotoxicity, short term_damage
# Saving Marine ecotoxicity, long term_midpoint
# Saving Marine ecotoxicity, long term_damage
# Saving Marine ecotoxicity, short term_midpoint
# Saving Marine ecotoxicity, short term_damage
# Saving Photochemical ozone formation, ecosystem quality_midpoint
# Saving Photochemical ozone formation, ecosystem quality_damage
# Saving Terrestrial ecotoxicity, long term_midpoint
# Saving Terrestrial ecotoxicity, long term_damage
# Saving Terrestrial ecotoxicity, short term_midpoint
# Saving Terrestrial ecotoxicity, short term_damage
# Saving Thermally polluted water_midpoint
# Saving Thermally polluted water_damage
# Saving Water availability, freshwater ecosystem_midpoint
# Saving Water availability, freshwater ecosystem_damage
# Saving Water availability, terrestrial ecosystem_midpoint
# Saving Water availability, terrestrial ecosystem_damage

# %%
import json

#load json
with open("/Users/romain/Github/edges/edges/data/ImpactWorld+ 2.1_Freshwater acidification_midpoint.json") as f:
    data = json.load(f)

def get_key(record):
    supplier = record["supplier"]
    consumer = record["consumer"]
    # If order doesn't matter in categories, sort them:
    categories = tuple(sorted(supplier["categories"]))
    return (
        supplier["name"],
        categories,
        supplier["matrix"],
        consumer["location"],
        consumer["matrix"]
    )

seen_keys = set()
duplicates = []
for rec in data:
    key = get_key(rec)
    if key in seen_keys:
        duplicates.append(rec)
    else:
        seen_keys.add(key)

print("Duplicates found:")
for dup in duplicates:
    print(dup)
# Out:
# Duplicates found:
